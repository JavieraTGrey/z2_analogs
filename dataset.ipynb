# %% [markdown]
# # Dependencies

# %%
# %matplotlib widget
import openpyxl
from astropy.io import fits, ascii
from astropy.coordinates import SkyCoord, match_coordinates_sky, FK5
import astropy.units as u
import matplotlib.pyplot as plt
import pandas as pd
from astropy.table import Table, QTable
import numpy as np
from catalog_compare import catalog_comparison, match

# %% [markdown]
# # MPA-JHU DATA

# %% [markdown]
# ## Viewing the data

# %%
InfoTable = Table.read('MPA-JHU/galSpecInfo-dr8.fits', format='fits')
InfoTable = InfoTable[['SPECOBJID', 'RA', 'DEC', 'Z', 'Z_ERR', 'RELIABLE', 'PRIMTARGET', 'SECTARGET',
             'TARGETTYPE', 'SPECTROTYPE', 'SUBCLASS', 'Z_WARNING']].to_pandas()
InfoTable
# Out:
#                       SPECOBJID          RA       DEC         Z     Z_ERR  \
# 0        b'299489676975171584 '  146.714203 -1.041304  0.021275  0.000009
# 1        b'299489951853078528 '  146.919449 -0.990492  0.213925  0.000052
# 2        b'299490226730985472 '  146.902283 -0.984913  0.652181  0.000133
# 3        b'299490501608892416 '  146.859833 -0.808902  0.126554  0.000062
# 4        b'299490776486799360 '  146.763397 -0.810433  0.448645  0.000168
# ...                         ...         ...       ...       ...       ...
# 1843195  b'                   '    0.000000  0.000000  0.000000  0.000000
# 1843196  b'                   '    0.000000  0.000000  0.000000  0.000000
# 1843197  b'                   '    0.000000  0.000000  0.000000  0.000000
# 1843198  b'                   '    0.000000  0.000000  0.000000  0.000000
# 1843199  b'                   '    0.000000  0.000000  0.000000  0.000000
#
#          RELIABLE  PRIMTARGET  SECTARGET              TARGETTYPE SPECTROTYPE  \
# 0               1          96          0  b'GALAXY             '   b'GALAXY'
# 1               1          64          0  b'GALAXY             '   b'GALAXY'
# 2               0           0          0  b'SERENDIPITY_BLUE   '   b'QSO   '
# 3               1          96          0  b'GALAXY             '   b'GALAXY'
# 4               1          32          0  b'GALAXY             '   b'GALAXY'
# ...           ...         ...        ...                     ...         ...
# 1843195         0           0          0  b'                   '   b'      '
# 1843196         0           0          0  b'                   '   b'      '
# 1843197         0           0          0  b'                   '   b'      '
# 1843198         0           0          0  b'                   '   b'      '
# 1843199         0           0          0  b'                   '   b'      '
#
#                          SUBCLASS  Z_WARNING
# 0        b'                     '          0
# 1        b'                     '          0
# 2        b'BROADLINE            '          0
# 3        b'                     '          0
# 4        b'                     '          0
# ...                           ...        ...
# 1843195  b'                     '          0
# 1843196  b'                     '          0
# 1843197  b'                     '          0
# 1843198  b'                     '          0
# 1843199  b'                     '          0
#
# [1843200 rows x 12 columns]

# %%
LineTable = Table.read('MPA-JHU/galSpecLine-dr8.fits', format='fits').to_pandas()
LineTable
# Out:
#                       SPECOBJID    MJD  PLATEID  FIBERID  SIGMA_BALMER  \
# 0        b'299489676975171584 '  51602      266        1    140.690125
# 1        b'299489951853078528 '  51602      266        2     77.367538
# 2        b'299490226730985472 '  51602      266        3    500.000000
# 3        b'299490501608892416 '  51602      266        4    500.000000
# 4        b'299490776486799360 '  51602      266        5    500.000000
# ...                         ...    ...      ...      ...           ...
# 1843195  b'                   '     -1       -1       -1      0.000000
# 1843196  b'                   '     -1       -1       -1      0.000000
# 1843197  b'                   '     -1       -1       -1      0.000000
# 1843198  b'                   '     -1       -1       -1      0.000000
# 1843199  b'                   '     -1       -1       -1      0.000000
#
#          SIGMA_BALMER_ERR  SIGMA_FORBIDDEN  SIGMA_FORBIDDEN_ERR  V_OFF_BALMER  \
# 0                4.170585       135.849838             6.414793     -0.882822
# 1               30.588966       127.082863            30.271038      0.775093
# 2               -0.000000       130.809418            12.581849    -31.929222
# 3               -0.000000       250.184357            47.851849    300.000000
# 4               -0.000000         1.000000            -0.000000   -300.000000
# ...                   ...              ...                  ...           ...
# 1843195          0.000000         0.000000             0.000000      0.000000
# 1843196          0.000000         0.000000             0.000000      0.000000
# 1843197          0.000000         0.000000             0.000000      0.000000
# 1843198          0.000000         0.000000             0.000000      0.000000
# 1843199          0.000000         0.000000             0.000000      0.000000
#
#          V_OFF_BALMER_ERR  ...    OII_FLUX   OII_FLUX_ERR    OII_VOFF  \
# 0                4.030681  ... -466.379456  399412.125000   43.492863
# 1               27.307035  ...   26.131104     469.464447  -30.449120
# 2               42.718376  ...   12.926446      10.988908  -54.456585
# 3               -0.000000  ...   12.239431      42.013542  300.000000
# 4               -0.000000  ...    0.797444       1.942454 -146.677582
# ...                   ...  ...         ...            ...         ...
# 1843195          0.000000  ...    0.000000       0.000000    0.000000
# 1843196          0.000000  ...    0.000000       0.000000    0.000000
# 1843197          0.000000  ...    0.000000       0.000000    0.000000
# 1843198          0.000000  ...    0.000000       0.000000    0.000000
# 1843199          0.000000  ...    0.000000       0.000000    0.000000
#
#          OII_CHI2  OIII_SIGMA  OIII_FLUX  OIII_FLUX_ERR   OIII_VOFF  \
# 0        0.249974  111.125435  68.174095       7.386366  -35.293663
# 1        0.511616   55.030731   2.864762       2.559604  300.000000
# 2        1.007290  126.656662  87.105797       6.679164   59.317154
# 3        0.901412  288.318573  21.261919       5.555132  150.371124
# 4        1.307248    1.000000  -0.211065       1.906883  -97.517990
# ...           ...         ...        ...            ...         ...
# 1843195  0.000000    0.000000   0.000000       0.000000    0.000000
# 1843196  0.000000    0.000000   0.000000       0.000000    0.000000
# 1843197  0.000000    0.000000   0.000000       0.000000    0.000000
# 1843198  0.000000    0.000000   0.000000       0.000000    0.000000
# 1843199  0.000000    0.000000   0.000000       0.000000    0.000000
#
#          OIII_CHI2  SPECTOFIBER
# 0         0.671645     0.768941
# 1         0.356733     0.786842
# 2         1.521129     0.918886
# 3         0.438892     0.803272
# 4         1.718731     0.811374
# ...            ...          ...
# 1843195   0.000000     0.000000
# 1843196   0.000000     0.000000
# 1843197   0.000000     0.000000
# 1843198   0.000000     0.000000
# 1843199   0.000000     0.000000
#
# [1843200 rows x 241 columns]

# %%
ExtraTable = Table.read('MPA-JHU/galSpecExtra-dr8.fits', format='fits').to_pandas()
ExtraTable
# Out:
#                       SPECOBJID  PLATEID    MJD  FIBERID  BPTCLASS  \
# 0        b'299489676975171584 '      266  51602        1         3
# 1        b'299489951853078528 '      266  51602        2        -1
# 2        b'299490226730985472 '      266  51602        3        -1
# 3        b'299490501608892416 '      266  51602        4        -1
# 4        b'299490776486799360 '      266  51602        5        -1
# ...                         ...      ...    ...      ...       ...
# 1843195  b'                   '       -1     -1       -1         0
# 1843196  b'                   '       -1     -1       -1         0
# 1843197  b'                   '       -1     -1       -1         0
# 1843198  b'                   '       -1     -1       -1         0
# 1843199  b'                   '       -1     -1       -1         0
#
#          LGM_TOT_P2P5  LGM_TOT_P16  LGM_TOT_P50  LGM_TOT_P84  LGM_TOT_P97P5  \
# 0           10.124110    10.202774    10.294701    10.389574      10.476274
# 1           10.943877    11.042439    11.162018    11.284745      11.420699
# 2        -9999.000000 -9999.000000 -9999.000000 -9999.000000   -9999.000000
# 3           11.231741    11.298348    11.373624    11.466687      11.550502
# 4        -9999.000000 -9999.000000 -9999.000000 -9999.000000   -9999.000000
# ...               ...          ...          ...          ...            ...
# 1843195      0.000000     0.000000     0.000000     0.000000       0.000000
# 1843196      0.000000     0.000000     0.000000     0.000000       0.000000
# 1843197      0.000000     0.000000     0.000000     0.000000       0.000000
# 1843198      0.000000     0.000000     0.000000     0.000000       0.000000
# 1843199      0.000000     0.000000     0.000000     0.000000       0.000000
#
#          ...  SPECSFR_TOT_P50  SPECSFR_TOT_P84  SPECSFR_TOT_P97P5  \
# 0        ...       -10.874370       -10.454710          -9.965384
# 1        ...       -11.567741       -10.802381         -10.270238
# 2        ...     -9999.000000     -9999.000000       -9999.000000
# 3        ...       -12.572567       -11.626812         -11.017391
# 4        ...     -9999.000000     -9999.000000       -9999.000000
# ...      ...              ...              ...                ...
# 1843195  ...         0.000000         0.000000           0.000000
# 1843196  ...         0.000000         0.000000           0.000000
# 1843197  ...         0.000000         0.000000           0.000000
# 1843198  ...         0.000000         0.000000           0.000000
# 1843199  ...         0.000000         0.000000           0.000000
#
#          SPECSFR_TOT_ENTROPY  SPECSFR_FIB_P2P5  SPECSFR_FIB_P16  \
# 0                  -5.592138        -13.750000       -11.970732
# 1                  -6.323584        -14.546667       -13.275001
# 2               -9999.000000      -9999.000000     -9999.000000
# 3                  -6.295079        -14.736842       -13.698148
# 4               -9999.000000      -9999.000000     -9999.000000
# ...                      ...               ...              ...
# 1843195             0.000000          0.000000         0.000000
# 1843196             0.000000          0.000000         0.000000
# 1843197             0.000000          0.000000         0.000000
# 1843198             0.000000          0.000000         0.000000
# 1843199             0.000000          0.000000         0.000000
#
#          SPECSFR_FIB_P50  SPECSFR_FIB_P84  SPECSFR_FIB_P97P5  \
# 0             -11.107513       -10.640601         -10.168965
# 1             -11.868675       -11.096316         -10.615625
# 2           -9999.000000     -9999.000000       -9999.000000
# 3             -12.473809       -11.535442         -10.910714
# 4           -9999.000000     -9999.000000       -9999.000000
# ...                  ...              ...                ...
# 1843195         0.000000         0.000000           0.000000
# 1843196         0.000000         0.000000           0.000000
# 1843197         0.000000         0.000000           0.000000
# 1843198         0.000000         0.000000           0.000000
# 1843199         0.000000         0.000000           0.000000
#
#          SPECSFR_FIB_ENTROPY
# 0                  -5.807676
# 1                  -6.285115
# 2               -9999.000000
# 3                  -6.321564
# 4               -9999.000000
# ...                      ...
# 1843195             0.000000
# 1843196             0.000000
# 1843197             0.000000
# 1843198             0.000000
# 1843199             0.000000
#
# [1843200 rows x 45 columns]

# %%
SDSS_tab = pd.concat((InfoTable, LineTable), axis=1)
SDSS_tab = pd.concat((SDSS_tab, ExtraTable), axis=1)

# %% [markdown]
# ## Select galaxies from the Table and clean sources

# %% [markdown]
# ### Coords and AGN cut

# %%
mask_coords = (SDSS_tab['RA']>-99) & (SDSS_tab['DEC']>-99) & (SDSS_tab['RELIABLE'] == 1.)

AGN_mask = ~((SDSS_tab['SUBCLASS'] == b'AGN                  ') | (SDSS_tab['SUBCLASS'] == b'AGN BROADLINE        '))

# %% [markdown]
# ### SNR cut

# %%
SDSS_tab['OIII_5007_SNR'] = SDSS_tab['OIII_5007_FLUX'] / SDSS_tab['OIII_5007_FLUX_ERR']
SDSS_tab['NII_6584_SNR'] = SDSS_tab['NII_6584_FLUX'] / SDSS_tab['NII_6584_FLUX_ERR']
SDSS_tab['H_ALPHA_SNR'] = SDSS_tab['H_ALPHA_FLUX'] / SDSS_tab['H_ALPHA_FLUX_ERR']
SDSS_tab['H_BETA_SNR'] = SDSS_tab['H_BETA_FLUX'] / SDSS_tab['H_BETA_FLUX_ERR']


SNR_mask = ((SDSS_tab['OIII_5007_SNR'] > 5.) & (SDSS_tab['NII_6584_SNR'] > 5.) &
            (SDSS_tab['H_ALPHA_SNR'] > 5.) & (SDSS_tab['H_BETA_SNR'] > 5.))

# %%
SDSS_tab = SDSS_tab[mask_coords & AGN_mask & SNR_mask]

# %% [markdown]
# ### properties

# %%
SDSS_tab['R3_S'] = np.log10(SDSS_tab['OIII_5007_FLUX'] / SDSS_tab['H_BETA_FLUX'])
SDSS_tab['N2_S'] = np.log10(SDSS_tab['NII_6584_FLUX'] / SDSS_tab['H_ALPHA_FLUX'])
SDSS_tab['R3_S_ERR'] = (1 / np.log(10))*((SDSS_tab['OIII_5007_FLUX_ERR'] / SDSS_tab['OIII_5007_FLUX']) ** 2
                      + (SDSS_tab['H_BETA_FLUX_ERR'] / SDSS_tab['H_BETA_FLUX']) ** 2) ** (1 / 2)
SDSS_tab['N2_S_ERR'] = (1 / np.log(10))*((SDSS_tab['NII_6584_FLUX_ERR'] / SDSS_tab['NII_6584_FLUX']) ** 2
                      + (SDSS_tab['H_ALPHA_FLUX_ERR'] / SDSS_tab['H_ALPHA_FLUX']) ** 2) ** (1 / 2)

# %% [markdown]
# ### BPT Diagram and cut

# %%
def steidel(x):
    return 0.66 / (x - 0.31) + 1.14 -0.05

def kewley(x):
    return 0.61 / (x - 0.47) + 1.19


bpt_selection = ((SDSS_tab['R3_S'] > steidel(SDSS_tab['N2_S'])) & (SDSS_tab['N2_S'] < -0.5) &
                (SDSS_tab['R3_S'] < kewley(SDSS_tab['N2_S'])))
SDSS_bpt_selected = SDSS_tab[bpt_selection]

# %%
def bpt_plot(N_ratio, O_ratio, contour=True, compare=False):
    fig = plt.figure()

    if contour is True:
        H, xedges, yedges = np.histogram2d(SDSS_tab['N2_S'], SDSS_tab['R3_S'], bins=150)
        levels = np.logspace(1.2, np.log10(H.max()), 10)
        plt.contour(H.T, levels=levels, extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]], colors='#5E4140')

    if compare is True:
        plt.scatter(SDSS_bpt_selected['N2_S'], SDSS_bpt_selected['R3_S'],
                    s=0.5, color='teal', alpha=0.4)

    plt.scatter(N_ratio, O_ratio, s=3, color='coral')

    x = np.linspace(-2.5, -0.5, 1900)
    plt.plot(x, steidel(x), color='#5E4140')
    plt.plot(x, kewley(x), color='#5E4140' )
    plt.plot((-0.5, -0.5), (np.min(kewley(x)), np.min(steidel(x))), color='#5E4140')

    plt.ylim(-1., 1.)
    plt.xlim(-2., 0.5)
    plt.xlabel('log([NII]/H_a)')
    plt.ylabel('log([OIII]/H_b)')
    plt.show()

# %%
bpt_plot(SDSS_bpt_selected['N2_S'], SDSS_bpt_selected['R3_S'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Nava galaxies on SDSS

# %%
nava_objects= ['00h21m01.02s +00d52m48.11s', '00h23m39.61s -09d48m48.72s', '01h36m30.59s -00d37m55.97s',
              '02h40m52.19s -08d28m27.41s', '02h52m34.29s +01d14m43.94s', '03h05m35.11s +00d40m59.24s',
              '09h50m23.31s +00d42m29.25s', '11h46m49.33s +00d53m46.09s', '12h26m11.89s +04d15m36.07s',
              '14h44m41.37s +04d09m41.73s', '14h48m05.38s -01d10m57.68s', '16h24m10.11s -00d22m02.60s',
              '21h01m14.39s -05d55m10.29s', '21h19m58.30s +00d52m33.55s', '22h12m43.05s +00d06m48.55s',
              '22h15m23.05s +00d02m46.79s', '22h25m10.13s -00d11m52.89s', '23h37m51.93s -00d10m00.50s']

SkyCoords_nava = [SkyCoord(i, frame=FK5, equinox='J2000.0') for i in nava_objects]
SkyCoords_nava = SkyCoord(SkyCoords_nava)

# %%
SkyCoords_SDSS = SkyCoord(ra=SDSS_bpt_selected.RA, dec=SDSS_bpt_selected.DEC, unit='deg', frame=FK5, equinox='J2000.0')

# %%
max_sep = 2*u.arcsec
catalog_match, under, over, unmatched = catalog_comparison(max_sep, SkyCoords_nava, SkyCoords_SDSS)
index, sep1 = match(SkyCoords_nava, SkyCoords_SDSS)

# %%
sep1.arcsec
# Out:
# array([0.13360325, 0.18450506, 0.06296315, 0.14495251, 0.14001777,
#        0.15847829, 0.21156379, 0.18550016, 0.12269153, 0.04207915,
#        0.04050078, 0.07462144, 0.0367284 , 0.1245473 , 0.13659314,
#        0.10661308, 0.05291626, 0.0541889 ])

# %%
sdss_analogs = SDSS_bpt_selected.iloc[index]
sdss_analogs
# Out:
#                       SPECOBJID          RA       DEC         Z     Z_ERR  \
# 90044    b'439223316213950464 '    5.254286  0.880023  0.098398  0.000011
# 284621   b'735339668748396544 '    5.915092 -9.813522  0.053035  0.000005
# 823766   b'1691125637219117056'   24.127474 -0.632222  0.059468  0.000005
# 150065   b'513494502204270592 '   40.217499 -8.474285  0.082218  0.000007
# 321683   b'797248221209454592 '   43.142914  1.245541  0.027945  0.000004
# 322503   b'798423599642863616 '   46.396332  0.683104  0.085573  0.000006
# 1700     b'300731025703593984 '  147.597183  0.708133  0.097702  0.000006
# 15291    b'318786936665827328 '  176.705582  0.896104  0.056519  0.000004
# 1629534  b'3242617920756410368'  186.549576  4.260018  0.094233  0.000005
# 237294   b'661039343871223808 '  221.172363  4.161592  0.038811  0.000008
# 463934   b'1035986009541601280'  222.022415 -1.182700  0.027398  0.000007
# 74426    b'409879001813772288 '  246.042145 -0.367383  0.031327  0.000006
# 273678   b'717307953417316352 '  315.309967 -5.919530  0.196179  0.000006
# 509193   b'1111371552277948416'  319.992950  0.875979  0.033754  0.000004
# 586038   b'1243114217410684928'  333.179413  0.113483  0.177042  0.000009
# 586110   b'1243134008619984896'  333.846069  0.046320  0.077447  0.000007
# 78837    b'422244936562272256 '  336.292206 -0.198011  0.066681  0.000005
# 304811   b'767911057829160960 '  354.466370 -0.166820  0.071730  0.000005
#
#          RELIABLE  PRIMTARGET  SECTARGET              TARGETTYPE SPECTROTYPE  \
# 90044           1           4          0  b'QSO                '   b'GALAXY'
# 284621          1           4          0  b'QSO                '   b'GALAXY'
# 823766          1         192          0  b'GALAXY             '   b'GALAXY'
# 150065          1           5          0  b'QSO                '   b'GALAXY'
# 321683          1           2          0  b'QSO                '   b'GALAXY'
# 322503          1           2          0  b'QSO                '   b'GALAXY'
# 1700            1           4          0  b'QSO                '   b'GALAXY'
# 15291           1           1          0  b'QSO                '   b'GALAXY'
# 1629534         1           2          0  b'QSO                '   b'GALAXY'
# 237294          1           1          0  b'QSO                '   b'GALAXY'
# 463934          1          66          0  b'QSO                '   b'GALAXY'
# 74426           1          68          0  b'QSO                '   b'GALAXY'
# 273678          1           4          0  b'QSO                '   b'GALAXY'
# 509193          1          64          0  b'GALAXY             '   b'GALAXY'
# 586038          1           2          0  b'QSO                '   b'GALAXY'
# 586110          1          64          0  b'GALAXY             '   b'GALAXY'
# 78837           1           4          0  b'QSO                '   b'GALAXY'
# 304811          1           2          0  b'QSO                '   b'GALAXY'
#
#          ... SPECSFR_FIB_P97P5  SPECSFR_FIB_ENTROPY OIII_5007_SNR  \
# 90044    ...         -7.207907            -4.275826    273.227966
# 284621   ...         -7.650739            -3.601265    168.275406
# 823766   ...         -7.899390            -3.639986    127.909592
# 150065   ...         -7.187820            -4.449047    169.801880
# 321683   ...         -8.092661            -3.053003    126.216660
# 322503   ...         -8.050574            -4.401502    138.361618
# 1700     ...         -7.005952            -4.715830    155.787582
# 15291    ...         -7.790000            -3.733890    113.727974
# 1629534  ...         -7.476315            -4.455638    140.076035
# 237294   ...         -7.606493            -4.072178     81.836494
# 463934   ...         -7.370440            -3.206332    159.616592
# 74426    ...         -7.453467            -3.119844    219.768478
# 273678   ...         -8.251424            -3.049089    173.952881
# 509193   ...         -8.320644            -3.031586    126.385437
# 586038   ...         -7.645918            -4.480963     98.122307
# 586110   ...         -7.051154            -4.397642    141.682220
# 78837    ...         -7.595238            -4.078555    135.122406
# 304811   ...         -7.479445            -4.212205    137.414352
#
#          NII_6584_SNR  H_ALPHA_SNR  H_BETA_SNR      R3_S      N2_S  R3_S_ERR  \
# 90044      180.899338   288.854401  218.104477  0.635548 -1.041750  0.002548
# 284621      54.212391   166.869583  120.736320  0.794038 -1.628973  0.004427
# 823766      17.077028   136.154785   90.163994  0.858043 -1.782569  0.005893
# 150065      63.118370   154.766083  134.887634  0.857585 -1.534407  0.004112
# 321683      23.969604   128.166489   79.677673  0.865039 -1.732835  0.006446
# 322503      34.714832   141.262482   71.896851  0.740713 -1.317919  0.006807
# 1700        72.113159   164.318787  114.017189  0.739335 -1.248647  0.004720
# 15291        9.360167   114.209908   80.172935  0.841534 -2.086792  0.006628
# 1629534     38.590099   130.953125  105.217941  0.827858 -1.631565  0.005162
# 237294      12.090849    93.915840   74.137283  0.862350 -2.025090  0.007904
# 463934      73.054077   149.224792  128.873825  0.837558 -1.675072  0.004331
# 74426      113.258118   188.762070  181.910095  0.773551 -1.554758  0.003099
# 273678      34.380615   134.648438   84.144844  0.717433 -1.339181  0.005733
# 509193      36.837139   119.909973   83.926094  0.727481 -1.440150  0.006212
# 586038      12.702683    68.219742   55.189892  0.705825 -1.272746  0.009028
# 586110      60.594841   128.153244  101.003502  0.817237 -1.350556  0.005281
# 78837       32.755695   122.456551  106.844635  0.807486 -1.779806  0.005182
# 304811      23.473101   125.032036   92.001663  0.842698 -1.802109  0.005681
#
#          N2_S_ERR
# 90044    0.002833
# 284621   0.008423
# 823766   0.025631
# 150065   0.007431
# 321683   0.018433
# 322503   0.012883
# 1700     0.006577
# 15291    0.046554
# 1629534  0.011733
# 237294   0.036216
# 463934   0.006619
# 74426    0.004472
# 273678   0.013037
# 509193   0.012333
# 586038   0.034777
# 586110   0.007928
# 78837    0.013725
# 304811   0.018825
#
# [18 rows x 306 columns]

# %%
bpt_plot(sdss_analogs.N2_S, sdss_analogs.R3_S, compare=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # MagE Data

# %%
nava_fluxes = pd.read_csv('nava_data/em_lines_final.csv')
nava_metal = pd.read_csv('nava_data/metals_lines.csv')
nava_extra = pd.read_csv('nava_data/extra_nava.csv')

# %%
magE_full = pd.concat((nava_fluxes, nava_metal, nava_extra), axis=1)
magE_full
# Out:
#    galname     [OII]3726  [OII]3726_err     [OII]3729  [OII]3729_err  \
# 0    J0021  3.823923e-14   5.526390e-16  5.857154e-14   4.944178e-16
# 1    J0023  9.828746e-15   4.934884e-17  1.349291e-14   5.749425e-17
# 2    J0136  6.147520e-15   1.028232e-16  8.280123e-15   1.147737e-16
# 3    J0240  1.057139e-14   1.559941e-16  9.884649e-15   1.590730e-16
# 4    J0252  4.105277e-15   1.092878e-16  6.235837e-15   1.189895e-16
# 5    J0305  9.361605e-15   2.181329e-16  1.202482e-14   2.479706e-16
# 6    J0950  1.449779e-14   9.764389e-17  1.718443e-14   9.607528e-17
# 7    J1146  7.950874e-16   8.548655e-18  1.157787e-15   1.000306e-17
# 8    J1226  1.124324e-14   5.246664e-17  1.375643e-14   5.329261e-17
# 9    J1444  2.589262e-15   4.264256e-17  3.366641e-15   4.206797e-17
# 10   J1448  4.777821e-14   1.642248e-16  6.455849e-14   1.916165e-16
# 11   J1624  9.775532e-16   2.231647e-17  1.186732e-15   2.940148e-17
# 12   J2101  1.763306e-14   9.214824e-17  2.306700e-14   9.886236e-17
# 13   J2119  1.322259e-14   1.306790e-16  1.780512e-14   1.681657e-16
# 14   J2212  2.531664e-15   4.457675e-17  3.270534e-15   4.547594e-17
# 15   J2215  1.381389e-15   7.596726e-18  1.671388e-15   7.767867e-18
# 16   J2225  1.447079e-15   1.104097e-17  1.889310e-15   1.188496e-17
# 17   J2337  8.363567e-15   9.813533e-17  1.227583e-14   9.972379e-17
#
#      [NeIII]3868  [NeIII]3868_err            Hd        Hd_err            Hg  \
# 0   2.329630e-14     1.303663e-16  1.589044e-14  9.834810e-17  2.994251e-14
# 1   7.107733e-15     3.663176e-17  3.491771e-15  2.580392e-17  6.438422e-15
# 2   6.428050e-15     6.999673e-17  2.518292e-15  4.848404e-17  5.012953e-15
# 3   1.938736e-14     1.253475e-16  9.876136e-15  8.009894e-17  1.733873e-14
# 4   5.522981e-15     7.980163e-17  2.327837e-15  5.184054e-17  4.459339e-15
# 5   5.692027e-15     1.003030e-16  3.183953e-15  7.527161e-17  5.833526e-15
# 6   8.562469e-15     4.457028e-17  3.481521e-15  2.150345e-17  5.295931e-15
# 7   1.474707e-15     8.927041e-18  4.617695e-16  3.704559e-18  8.392631e-16
# 8   1.493265e-14     5.542594e-17  5.756431e-15  2.343113e-17  9.243072e-15
# 9   7.565282e-15     6.227745e-17  2.405109e-15  2.333143e-17  3.974723e-15
# 10  6.395318e-14     1.606602e-16  2.659901e-14  9.059382e-17  4.445828e-14
# 11  8.086364e-16     1.454839e-17  4.454973e-16  1.297349e-17  9.443430e-16
# 12  7.368464e-15     4.093467e-17  3.888497e-15  2.732403e-17  7.713376e-15
# 13  6.271722e-15     9.280267e-17  3.388233e-15  4.637536e-17  5.380110e-15
# 14  1.432358e-15     2.812291e-17  8.229724e-16  1.954759e-17  1.669105e-15
# 15  1.331249e-15     5.361582e-18  5.975361e-16  3.483755e-18  1.123320e-15
# 16  1.952793e-15     7.970337e-18  9.648141e-16  5.310426e-18  1.698651e-15
# 17  1.355815e-14     6.707991e-17  5.400843e-15  4.416129e-17  1.060076e-14
#
#     ...  log_M  log_SFR     Av      ne    chi2  Age_Gyr_err  log_M_err  \
# 0   ...   9.06     1.49  0.890  320.82   0.007          3.0       0.29
# 1   ...   8.49     0.67  0.930  507.99   3.527          2.1       0.06
# 2   ...   7.79     0.03  0.929  539.32   1.960          3.0       0.13
# 3   ...   7.87     0.62  0.780  478.82   0.910          3.0       0.22
# 4   ...   7.27    -0.55  0.930  480.21   2.775          1.9       0.05
# 5   ...   8.09     0.27  0.930  406.37   2.813          2.0       0.04
# 6   ...   8.51     0.99  0.870  331.40   0.019          3.0       0.31
# 7   ...   7.65    -0.09  0.930  495.52   2.892          3.0       0.15
# 8   ...   8.15     0.68  0.790  348.67   0.063          3.0       0.31
# 9   ...   6.83    -0.66  0.290  435.93   2.644          3.1       0.30
# 10  ...   7.89     0.44  0.840  422.99   0.326          3.1       0.30
# 11  ...   8.27     0.69  0.850  422.85   0.478          3.1       0.23
# 12  ...   8.99     1.27  0.929  504.23   0.252          3.0       0.16
# 13  ...   7.76    -0.07  0.930  452.39  10.465          1.6       0.02
# 14  ...   8.34     0.83  0.900  488.93   0.111          3.1       0.29
# 15  ...   8.06     0.49  0.930  462.52   0.249          3.0       0.26
# 16  ...   8.18     0.60  0.910  616.55   0.614          3.0       0.27
# 17  ...   7.86     0.29  0.930  483.75   0.702          3.0       0.26
#
#     log_SFR_err   Av_err  ne_err
# 0          0.07  0.15000  428.04
# 1          0.04  0.00400  472.35
# 2          0.05  0.01900  472.65
# 3          0.11  0.29000  467.72
# 4          0.04  0.00200  470.70
# 5          0.04  0.00100  457.19
# 6          0.08  0.19000  432.39
# 7          0.05  0.04000  472.08
# 8          0.11  0.28000  438.91
# 9          0.16  0.26000  463.81
# 10         0.09  0.24000  461.72
# 11         0.09  0.22000  461.95
# 12         0.04  0.02500  471.44
# 13         0.02  0.00015  461.77
# 14         0.06  0.14000  470.53
# 15         0.04  0.05000  467.18
# 16         0.06  0.10000  460.72
# 17         0.04  0.05000  467.29
#
# [18 rows x 101 columns]

# %%
sdss_analogs['LGM_TOT_P5016_ERR'] = np.abs(sdss_analogs.LGM_TOT_P50.values -  sdss_analogs.LGM_TOT_P16.values)
sdss_analogs['SFR_TOT_P5016_ERR'] = np.abs(sdss_analogs.SFR_TOT_P50.values -  sdss_analogs.SFR_TOT_P16.values)
# Out:
# /tmp/ipykernel_25147/409969354.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdss_analogs['LGM_TOT_P5016_ERR'] = np.abs(sdss_analogs.LGM_TOT_P50.values -  sdss_analogs.LGM_TOT_P16.values)
# /tmp/ipykernel_25147/409969354.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdss_analogs['SFR_TOT_P5016_ERR'] = np.abs(sdss_analogs.SFR_TOT_P50.values -  sdss_analogs.SFR_TOT_P16.values)

# %% [markdown]
# # Save

# %%
names = ['J0021+0052', 'J0023-0948', 'J0136-0037', 'J0240-0828', 'J0252+0114',
          'J0305+0040', 'J0950+0042', 'J1146+0053', 'J1226+0415', 'J1444+0409',
          'J1448-0110', 'J1624-0022', 'J2101-0555', 'J2119+0052', 'J2212+0006','J2215+0002', 'J2215-0011', 'J2337-0010']

master = pd.DataFrame({
    'ID': names,
    'magE_RA': SkyCoords_nava.ra.deg,
    'magE_DEC': SkyCoords_nava.dec.deg,
    'sdss_RA': sdss_analogs.RA,
    'sdss_DEC': sdss_analogs.DEC,
    'sdss_data': np.full(18, 'sdss')
})


master = pd.concat((master.reset_index(drop=True), sdss_analogs.reset_index(drop=True)), axis=1)

master

master['magE'] = np.full(18, 'magE')

master = pd.concat((master, magE_full), axis=1)

# %%
sdss_analogs.RA, sdss_analogs.DEC
# Out:
# (90044        5.254286
#  284621       5.915092
#  823766      24.127474
#  150065      40.217499
#  321683      43.142914
#  322503      46.396332
#  1700       147.597183
#  15291      176.705582
#  1629534    186.549576
#  237294     221.172363
#  463934     222.022415
#  74426      246.042145
#  273678     315.309967
#  509193     319.992950
#  586038     333.179413
#  586110     333.846069
#  78837      336.292206
#  304811     354.466370
#  Name: RA, dtype: float32,
#  90044      0.880023
#  284621    -9.813522
#  823766    -0.632222
#  150065    -8.474285
#  321683     1.245541
#  322503     0.683104
#  1700       0.708133
#  15291      0.896104
#  1629534    4.260018
#  237294     4.161592
#  463934    -1.182700
#  74426     -0.367383
#  273678    -5.919530
#  509193     0.875979
#  586038     0.113483
#  586110     0.046320
#  78837     -0.198011
#  304811    -0.166820
#  Name: DEC, dtype: float32)

# %% [markdown]
# # Cecilia/MOSFIRE

# %%
cecilia = Table.read('CECILIA/cecilia-cat.fits')
cecilia
# Out:
# <Table length=34>
# LABEL          RA        ...        KMAG                KERR
# bytes6      float64      ...      float64             float64
# ------ ----------------- ... ------------------ -------------------
#  BX537       356.6065305 ...  23.47490119934082 0.10217147320508957
#  BX348       356.6143693 ... 23.170000076293945 0.09093035757541656
#  RK120       356.6093603 ...  22.54279899597168 0.12032967060804367
#  BX418       999.9999999 ...  23.69070053100586 0.09770342707633972
#  BX336       356.6231682 ... 22.705900192260742 0.07554852962493896
#  BX523       356.6464617 ...  24.03380012512207 0.13288690149784088
#  BX274       356.6090119 ... 25.690595626831055                99.0
#  BX390       356.6030244 ...  23.36240005493164 0.09842895716428757
#  BX391       356.6170149 ... 23.589799880981445 0.14395812153816223
#    ...               ... ...                ...                 ...
# NB2089 356.6240833333333 ...               99.0                99.0
#  BM118        356.584293 ... 22.845598220825195 0.10773017257452011
#  BX429       356.6052765 ... 23.457101821899414 0.17040343582630157
#  BX341       356.5967791 ... 24.717498779296875 0.29707884788513184
#  BM113        356.592698 ... 24.810300827026367  0.2690582573413849
#  fBM40       356.6373901 ... 24.961999893188477  0.2253720909357071
#   MD43       356.5853132 ...  25.25320053100586 0.32831212878227234
#  BX611       356.5888957 ...  25.28084945678711                99.0
#  BM192       356.6084492 ... 23.057498931884766 0.09462615847587585
#    D27       356.6423519 ... 25.452817916870117                99.0

# %%
cecilia['R3'] = np.log10(cecilia['FO3N'][:, 1] / cecilia['FHB'])

cecilia['N2'] = np.log10(cecilia['FN2'][:, 1] / cecilia['FHA'])

cecilia['S2'] = np.log10(np.sum(cecilia['FS2'], axis=1)/ cecilia['FHA'])

cecilia['R23'] = np.log10( ( np.sum(cecilia['FO3N'], axis=1) +
                  np.sum(cecilia['FO2'], axis=1) ) /
                  cecilia['FHB'] )

cecilia['O32'] = np.log10(  np.sum(cecilia['FO3N'], axis=1) /
                  np.sum(cecilia['FO2'], axis=1)  )

cecilia['N202'] = np.log10( cecilia['FN2'][:, 1] /
                            np.sum(cecilia['FO2'], axis=1) )

cecilia['N2S2'] = np.log10( cecilia['FN2'][:, 1] /
                            np.sum(cecilia['FS2'], axis=1) )

cecilia['O3N2'] = cecilia['R3'] - cecilia['N2']

cecilia['Ne3O2'] = np.log10(cecilia['FNE3'] / np.sum(cecilia['FO2'], axis=1))
# Out:
# /tmp/ipykernel_25147/2720314054.py:1: RuntimeWarning: invalid value encountered in divide
#   cecilia['R3'] = np.log10(cecilia['FO3N'][:, 1] / cecilia['FHB'])
# /tmp/ipykernel_25147/2720314054.py:1: RuntimeWarning: divide by zero encountered in log10
#   cecilia['R3'] = np.log10(cecilia['FO3N'][:, 1] / cecilia['FHB'])
# /tmp/ipykernel_25147/2720314054.py:3: RuntimeWarning: invalid value encountered in divide
#   cecilia['N2'] = np.log10(cecilia['FN2'][:, 1] / cecilia['FHA'])
# /tmp/ipykernel_25147/2720314054.py:3: RuntimeWarning: invalid value encountered in log10
#   cecilia['N2'] = np.log10(cecilia['FN2'][:, 1] / cecilia['FHA'])
# /tmp/ipykernel_25147/2720314054.py:5: RuntimeWarning: divide by zero encountered in divide
#   cecilia['S2'] = np.log10(np.sum(cecilia['FS2'], axis=1)/ cecilia['FHA'])
# /tmp/ipykernel_25147/2720314054.py:5: RuntimeWarning: divide by zero encountered in log10
#   cecilia['S2'] = np.log10(np.sum(cecilia['FS2'], axis=1)/ cecilia['FHA'])
# /tmp/ipykernel_25147/2720314054.py:5: RuntimeWarning: invalid value encountered in log10
#   cecilia['S2'] = np.log10(np.sum(cecilia['FS2'], axis=1)/ cecilia['FHA'])
# /tmp/ipykernel_25147/2720314054.py:7: RuntimeWarning: divide by zero encountered in divide
#   cecilia['R23'] = np.log10( ( np.sum(cecilia['FO3N'], axis=1) +
# /tmp/ipykernel_25147/2720314054.py:7: RuntimeWarning: invalid value encountered in divide
#   cecilia['R23'] = np.log10( ( np.sum(cecilia['FO3N'], axis=1) +
# /tmp/ipykernel_25147/2720314054.py:11: RuntimeWarning: divide by zero encountered in divide
#   cecilia['O32'] = np.log10(  np.sum(cecilia['FO3N'], axis=1) /
# /tmp/ipykernel_25147/2720314054.py:11: RuntimeWarning: invalid value encountered in divide
#   cecilia['O32'] = np.log10(  np.sum(cecilia['FO3N'], axis=1) /
# /tmp/ipykernel_25147/2720314054.py:11: RuntimeWarning: divide by zero encountered in log10
#   cecilia['O32'] = np.log10(  np.sum(cecilia['FO3N'], axis=1) /
# /tmp/ipykernel_25147/2720314054.py:14: RuntimeWarning: divide by zero encountered in divide
#   cecilia['N202'] = np.log10( cecilia['FN2'][:, 1] /
# /tmp/ipykernel_25147/2720314054.py:14: RuntimeWarning: invalid value encountered in divide
#   cecilia['N202'] = np.log10( cecilia['FN2'][:, 1] /
# /tmp/ipykernel_25147/2720314054.py:14: RuntimeWarning: invalid value encountered in log10
#   cecilia['N202'] = np.log10( cecilia['FN2'][:, 1] /
# /tmp/ipykernel_25147/2720314054.py:17: RuntimeWarning: divide by zero encountered in divide
#   cecilia['N2S2'] = np.log10( cecilia['FN2'][:, 1] /
# /tmp/ipykernel_25147/2720314054.py:17: RuntimeWarning: divide by zero encountered in log10
#   cecilia['N2S2'] = np.log10( cecilia['FN2'][:, 1] /
# /tmp/ipykernel_25147/2720314054.py:17: RuntimeWarning: invalid value encountered in log10
#   cecilia['N2S2'] = np.log10( cecilia['FN2'][:, 1] /
# /tmp/ipykernel_25147/2720314054.py:22: RuntimeWarning: invalid value encountered in divide
#   cecilia['Ne3O2'] = np.log10(cecilia['FNE3'] / np.sum(cecilia['FO2'], axis=1))
# /tmp/ipykernel_25147/2720314054.py:22: RuntimeWarning: divide by zero encountered in log10
#   cecilia['Ne3O2'] = np.log10(cecilia['FNE3'] / np.sum(cecilia['FO2'], axis=1))
# /tmp/ipykernel_25147/2720314054.py:22: RuntimeWarning: invalid value encountered in log10
#   cecilia['Ne3O2'] = np.log10(cecilia['FNE3'] / np.sum(cecilia['FO2'], axis=1))

# %%
cecilia['R3_ERR'] = (1/np.log(10)) * np.sqrt( (cecilia['EO3N'][:, 1] ** 2 /
                                            cecilia['FO3N'][:, 1] ** 2) +
                                          (cecilia['EHB'] ** 2 /
                                           cecilia['FHB'] ** 2) )

cecilia['N2_ERR'] = (1/np.log(10)) * np.sqrt( (cecilia['EN2'][:, 1]**2 /
                                            cecilia['EN2'][:, 1]**2) +
                                          (cecilia['EHA']**2 /
                                           cecilia['FHA']**2) )

cecilia['S2_ERR'] = (1/np.log(10)) * np.sqrt( (cecilia['ES2'][:, 0]**2 /
                                            (np.sum(cecilia['FS2'], axis=1))**2) +
                                          (cecilia['ES2'][:, 1]**2 /
                                           (np.sum(cecilia['FS2'], axis=1))**2) +
                                          (cecilia['EHA']**2 / cecilia['FHA']**2) )

cecilia['R23_ERR'] = (1/np.log(10)) * np.sqrt( (cecilia['EO2'][:, 0]**2 /
                                             ( np.sum(cecilia['FO3N'], axis=1) +
                                              np.sum(cecilia['FO2'], axis=1) )**2) +
                                           (cecilia['EO2'][:, 1]**2 /
                                            ( np.sum(cecilia['FO3N'], axis=1) +
                                             np.sum(cecilia['FO2'], axis=1) )**2) +
                                           (cecilia['EO3N'][:, 0]**2 /
                                            ( np.sum(cecilia['FO3N'], axis=1) +
                                             np.sum(cecilia['FO2'], axis=1) )**2) +
                                           (cecilia['EO3N'][:, 1]**2 /
                                            ( np.sum(cecilia['FO3N'], axis=1) +
                                             np.sum(cecilia['FO2'], axis=1) )**2) +
                                           (cecilia['EHB']**2/ cecilia['FHB']**2) )

cecilia['O32_ERR'] = (1/np.log(10)) * np.sqrt( (cecilia['EO2'][:, 0]**2 /
                                             (np.sum(cecilia['FO2'], axis=1) )**2) +
                                           (cecilia['EO2'][:, 1]**2 /
                                            (np.sum(cecilia['FO2'], axis=1) )**2) +
                                           (cecilia['EO3N'][:, 0]**2 /
                                            (np.sum(cecilia['FO3N'], axis=1) )**2) +
                                           (cecilia['EO3N'][:, 1]**2 /
                                            ( np.sum(cecilia['FO3N'], axis=1) )**2) )

cecilia['N2O2_ERR'] =  (1/np.log(10)) * np.sqrt( (cecilia['EN2'][:, 1]**2 /
                                                  cecilia['EN2'][:, 1]**2) +
                                                (cecilia['EO2'][:, 0]**2 /
                                                 (np.sum(cecilia['FO2'], axis=1) )**2) +
                                                (cecilia['EO2'][:, 1]**2 /
                                                 (np.sum(cecilia['FO2'], axis=1) )**2) )

cecilia['N2S2_ERR'] = (1/np.log(10)) * np.sqrt( (cecilia['EN2'][:, 1]**2 /
                                                  cecilia['EN2'][:, 1]**2) +
                                               (cecilia['ES2'][:, 0]**2 /
                                                (np.sum(cecilia['FS2'], axis=1))**2) +
                                               (cecilia['ES2'][:, 1]**2 /
                                                (np.sum(cecilia['FS2'], axis=1))**2) )

cecilia['O3N2_ERR'] = np.sqrt( (cecilia['R3_ERR'])**2 + (cecilia['N2_ERR'])**2)

cecilia['Ne3O2_ERR'] = (1/np.log(10)) * np.sqrt( (cecilia['ENE3'] / cecilia['FNE3'])**2 +
                                               (cecilia['EO2'][:, 0]**2 /
                                                (np.sum(cecilia['FO2'], axis=1) **2)) +
                                                (cecilia['EO2'][:, 1]**2 /
                                                 (np.sum(cecilia['FO2'], axis=1) )**2) )
# Out:
# /tmp/ipykernel_25147/742067919.py:1: RuntimeWarning: invalid value encountered in divide
#   cecilia['R3_ERR'] = (1/np.log(10)) * np.sqrt( (cecilia['EO3N'][:, 1] ** 2 /
# /tmp/ipykernel_25147/742067919.py:3: RuntimeWarning: divide by zero encountered in divide
#   (cecilia['EHB'] ** 2 /
# /tmp/ipykernel_25147/742067919.py:3: RuntimeWarning: invalid value encountered in divide
#   (cecilia['EHB'] ** 2 /
# /tmp/ipykernel_25147/742067919.py:6: RuntimeWarning: invalid value encountered in divide
#   cecilia['N2_ERR'] = (1/np.log(10)) * np.sqrt( (cecilia['EN2'][:, 1]**2 /
# /tmp/ipykernel_25147/742067919.py:8: RuntimeWarning: invalid value encountered in divide
#   (cecilia['EHA']**2 /
# /tmp/ipykernel_25147/742067919.py:11: RuntimeWarning: invalid value encountered in divide
#   cecilia['S2_ERR'] = (1/np.log(10)) * np.sqrt( (cecilia['ES2'][:, 0]**2 /
# /tmp/ipykernel_25147/742067919.py:13: RuntimeWarning: invalid value encountered in divide
#   (cecilia['ES2'][:, 1]**2 /
# /tmp/ipykernel_25147/742067919.py:15: RuntimeWarning: invalid value encountered in divide
#   (cecilia['EHA']**2 / cecilia['FHA']**2) )
# /tmp/ipykernel_25147/742067919.py:17: RuntimeWarning: invalid value encountered in divide
#   cecilia['R23_ERR'] = (1/np.log(10)) * np.sqrt( (cecilia['EO2'][:, 0]**2 /
# /tmp/ipykernel_25147/742067919.py:20: RuntimeWarning: invalid value encountered in divide
#   (cecilia['EO2'][:, 1]**2 /
# /tmp/ipykernel_25147/742067919.py:23: RuntimeWarning: invalid value encountered in divide
#   (cecilia['EO3N'][:, 0]**2 /
# /tmp/ipykernel_25147/742067919.py:26: RuntimeWarning: invalid value encountered in divide
#   (cecilia['EO3N'][:, 1]**2 /
# /tmp/ipykernel_25147/742067919.py:29: RuntimeWarning: divide by zero encountered in divide
#   (cecilia['EHB']**2/ cecilia['FHB']**2) )
# /tmp/ipykernel_25147/742067919.py:29: RuntimeWarning: invalid value encountered in divide
#   (cecilia['EHB']**2/ cecilia['FHB']**2) )
# /tmp/ipykernel_25147/742067919.py:31: RuntimeWarning: invalid value encountered in divide
#   cecilia['O32_ERR'] = (1/np.log(10)) * np.sqrt( (cecilia['EO2'][:, 0]**2 /
# /tmp/ipykernel_25147/742067919.py:33: RuntimeWarning: invalid value encountered in divide
#   (cecilia['EO2'][:, 1]**2 /
# /tmp/ipykernel_25147/742067919.py:35: RuntimeWarning: invalid value encountered in divide
#   (cecilia['EO3N'][:, 0]**2 /
# /tmp/ipykernel_25147/742067919.py:37: RuntimeWarning: invalid value encountered in divide
#   (cecilia['EO3N'][:, 1]**2 /
# /tmp/ipykernel_25147/742067919.py:40: RuntimeWarning: invalid value encountered in divide
#   cecilia['N2O2_ERR'] =  (1/np.log(10)) * np.sqrt( (cecilia['EN2'][:, 1]**2 /
# /tmp/ipykernel_25147/742067919.py:42: RuntimeWarning: invalid value encountered in divide
#   (cecilia['EO2'][:, 0]**2 /
# /tmp/ipykernel_25147/742067919.py:44: RuntimeWarning: invalid value encountered in divide
#   (cecilia['EO2'][:, 1]**2 /
# /tmp/ipykernel_25147/742067919.py:47: RuntimeWarning: invalid value encountered in divide
#   cecilia['N2S2_ERR'] = (1/np.log(10)) * np.sqrt( (cecilia['EN2'][:, 1]**2 /
# /tmp/ipykernel_25147/742067919.py:49: RuntimeWarning: invalid value encountered in divide
#   (cecilia['ES2'][:, 0]**2 /
# /tmp/ipykernel_25147/742067919.py:51: RuntimeWarning: invalid value encountered in divide
#   (cecilia['ES2'][:, 1]**2 /
# /tmp/ipykernel_25147/742067919.py:56: RuntimeWarning: invalid value encountered in divide
#   cecilia['Ne3O2_ERR'] = (1/np.log(10)) * np.sqrt( (cecilia['ENE3'] / cecilia['FNE3'])**2 +
# /tmp/ipykernel_25147/742067919.py:57: RuntimeWarning: invalid value encountered in divide
#   (cecilia['EO2'][:, 0]**2 /
# /tmp/ipykernel_25147/742067919.py:59: RuntimeWarning: invalid value encountered in divide
#   (cecilia['EO2'][:, 1]**2 /

# %% [markdown]
# ## Save

# %%
cecilia.write('mosfire.fits', format='fits', overwrite=True)

# %% [markdown]
# # Ratios

# %%
def error_sum(num_list, dem_list, name, mage=True):
    if mage is True:
        err_name = '_ERR'
        catalog = master
    else:
        catalog = SDSS_tab
        err_name ='_ERR'

    fluxes = []
    fluxes_err = []

    for i in num_list:
        num = catalog[i]
        num_err = catalog[i + err_name]
        fluxes.append(num)
        fluxes_err.append(num_err)
    for j in dem_list:
        dem = catalog[j]
        dem_err = catalog[j + err_name]
        fluxes.append(dem)
        fluxes_err.append(dem_err)

    fluxes = np.array(fluxes)
    fluxes_err = np.array(fluxes_err)

    value = np.log10(
        np.sum(fluxes[:len(num_list)], axis=0) / np.sum(fluxes[len(num_list):], axis=0)
    )

    num_err = np.sum( (np.array(fluxes_err[:len(num_list)])**2) /
                     (np.sum(fluxes[:len(num_list)])**2), axis=0 )

    dem_err = np.sum( (np.array(fluxes_err[len(num_list):])**2) /
                     (np.sum(fluxes[len(num_list):])**2), axis=0 )

    err = (1/np.log(10)) * (num_err + dem_err)**(1/2)

    if mage is True:
        index = master.columns.get_loc('magE')
        master.insert(index, name, value)
        master.insert(index+1, name + err_name, err)
    else:
        catalog[name] = value
        catalog[name + err_name] = err

# %%
error_sum(['OIII_4959_FLUX', 'OIII_5007_FLUX'],
          ['OII_3726_FLUX', 'OII_3729_FLUX'], 'O32_S', mage=True)

# %%
error_sum(['NEIII_3869_FLUX'],
         ['OII_3726_FLUX', 'OII_3729_FLUX'], 'Ne3O2_S', mage=True)

# %%
error_sum(['NII_6584_FLUX'],
         ['OII_3726_FLUX', 'OII_3729_FLUX'], 'N2O2_S', mage=True)

# %%
error_sum(['NII_6584_FLUX'],
         ['SII_6717_FLUX', 'SII_6731_FLUX'], 'N2S2_S', mage=True)

# %%
error_sum(['OII_3726_FLUX', 'OII_3729_FLUX', 'OIII_4959_FLUX', 'OIII_5007_FLUX'],
         ['H_ALPHA_FLUX'], 'R23_S', mage=True)

# %%
error_sum(['OIII_5007_FLUX'],
         ['NII_6584_FLUX'], 'R3N2_S', mage=True)

# %%
O3N2_S = master.R3_S - master.N2_S
O3N2_S_ERR = np.sqrt(master.R3_S_ERR ** 2 + master.N2_S_ERR ** 2)
index = master.columns.get_loc('magE')
master.insert(index, 'O3N2_S', O3N2_S)
master.insert(index+1, 'O3N2_S_ERR', O3N2_S_ERR)

# %%
Ne3O2 = np.log10(
    master['[NeIII]3868'] / (master['[OII]3726'] + master['[OII]3729'])
)
Ne3O2_err = (1/np.log(10))*np.sqrt((master['[NeIII]3868_err'] / master['[NeIII]3868']) ** 2 +
                                   (master['[OII]3726_err'] / (master['[OII]3726'] + master['[OII]3729'])) ** 2 +
                                   (master['[OII]3729_err'] / (master['[OII]3726'] + master['[OII]3729'])) ** 2)
index1 = master.columns.get_loc('Unnamed: 0')
master.insert(index1, 'Ne3O2', Ne3O2)
master.insert(index1+1, 'Ne3O2_err', Ne3O2_err)

# %%
error_sum(['SII_6717_FLUX', 'SII_6731_FLUX'],
          ['H_ALPHA_FLUX'], 'S2_S', mage=True)

# %%
error_sum(['OIII_4959_FLUX', 'OIII_5007_FLUX'],
          ['OII_3726_FLUX', 'OII_3729_FLUX'], 'O32_S', mage=False)

error_sum(['NEIII_3869_FLUX'],
         ['OII_3726_FLUX', 'OII_3729_FLUX'], 'Ne3O2_S', mage=False)

error_sum(['NII_6584_FLUX'],
         ['OII_3726_FLUX', 'OII_3729_FLUX'], 'N2O2_S', mage=False)

error_sum(['NII_6584_FLUX'],
         ['SII_6717_FLUX', 'SII_6731_FLUX'], 'N2S2_S', mage=False)

error_sum(['OII_3726_FLUX', 'OII_3729_FLUX', 'OIII_4959_FLUX', 'OIII_5007_FLUX'],
         ['H_BETA_FLUX'], 'R23_S', mage=False)

error_sum(['OIII_5007_FLUX'],
         ['NII_6584_FLUX'], 'R3N2_S', mage=False)

O3N2_S = SDSS_tab.R3_S - SDSS_tab.N2_S
O3N2_S_ERR = np.sqrt(SDSS_tab.R3_S_ERR ** 2 + SDSS_tab.N2_S_ERR ** 2)
SDSS_tab['O3N2_S'] = O3N2_S
SDSS_tab['O3N2_S_ERR'] = O3N2_S_ERR

Ne3O2 = np.log10(
    SDSS_tab['NEIII_3869_FLUX'] / (SDSS_tab['OII_3726_FLUX'] + SDSS_tab['OII_3729_FLUX'])
)
Ne3O2_err = (1/np.log(10))*np.sqrt((SDSS_tab['NEIII_3869_FLUX_ERR'] / SDSS_tab['NEIII_3869_FLUX']) ** 2 +
                                   (SDSS_tab['OII_3726_FLUX_ERR'] /
                                    (SDSS_tab['OII_3726_FLUX'] + SDSS_tab['OII_3729_FLUX'])) ** 2 +
                                   (SDSS_tab['OII_3729_FLUX_ERR'] /
                                    (SDSS_tab['OII_3726_FLUX'] + SDSS_tab['OII_3729_FLUX'])) ** 2)
SDSS_tab['Ne3O2'] = Ne3O2
SDSS_tab['Ne3O2_err'] = Ne3O2_err
# Out:
# /tmp/ipykernel_25147/3238309771.py:27: RuntimeWarning: divide by zero encountered in divide
#   np.sum(fluxes[:len(num_list)], axis=0) / np.sum(fluxes[len(num_list):], axis=0)
# /tmp/ipykernel_25147/3238309771.py:26: RuntimeWarning: invalid value encountered in log10
#   value = np.log10(
# /tmp/ipykernel_25147/3238309771.py:27: RuntimeWarning: divide by zero encountered in divide
#   np.sum(fluxes[:len(num_list)], axis=0) / np.sum(fluxes[len(num_list):], axis=0)
# /tmp/ipykernel_25147/3238309771.py:27: RuntimeWarning: invalid value encountered in divide
#   np.sum(fluxes[:len(num_list)], axis=0) / np.sum(fluxes[len(num_list):], axis=0)
# /tmp/ipykernel_25147/3238309771.py:26: RuntimeWarning: divide by zero encountered in log10
#   value = np.log10(
# /tmp/ipykernel_25147/3238309771.py:26: RuntimeWarning: invalid value encountered in log10
#   value = np.log10(
# /tmp/ipykernel_25147/3238309771.py:27: RuntimeWarning: divide by zero encountered in divide
#   np.sum(fluxes[:len(num_list)], axis=0) / np.sum(fluxes[len(num_list):], axis=0)
# /tmp/ipykernel_25147/3238309771.py:26: RuntimeWarning: invalid value encountered in log10
#   value = np.log10(
# /tmp/ipykernel_25147/3238309771.py:27: RuntimeWarning: divide by zero encountered in divide
#   np.sum(fluxes[:len(num_list)], axis=0) / np.sum(fluxes[len(num_list):], axis=0)
# /tmp/ipykernel_25147/3238309771.py:26: RuntimeWarning: invalid value encountered in log10
#   value = np.log10(
# /tmp/ipykernel_25147/3238309771.py:26: RuntimeWarning: invalid value encountered in log10
#   value = np.log10(
# /workspace/home/javiera/miniconda3/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /workspace/home/javiera/miniconda3/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
error_sum(['SII_6717_FLUX', 'SII_6731_FLUX'],
          ['H_ALPHA_FLUX'], 'S2_S', mage=False)
# Out:
# /tmp/ipykernel_25147/3238309771.py:26: RuntimeWarning: divide by zero encountered in log10
#   value = np.log10(
# /tmp/ipykernel_25147/3238309771.py:26: RuntimeWarning: invalid value encountered in log10
#   value = np.log10(

# %% [markdown]
# # Master Table

# %%
master.to_excel('master.xlsx', index=True)
master.to_csv('master.csv', index=True)

master
# Out:
#             ID     magE_RA  magE_DEC     sdss_RA  sdss_DEC sdss_data  \
# 0   J0021+0052    5.254250  0.880031    5.254286  0.880023      sdss
# 1   J0023-0948    5.915042 -9.813533    5.915092 -9.813522      sdss
# 2   J0136-0037   24.127458 -0.632214   24.127474 -0.632222      sdss
# 3   J0240-0828   40.217458 -8.474281   40.217499 -8.474285      sdss
# 4   J0252+0114   43.142875  1.245539   43.142914  1.245541      sdss
# 5   J0305+0040   46.396292  0.683122   46.396332  0.683104      sdss
# 6   J0950+0042  147.597125  0.708125  147.597183  0.708133      sdss
# 7   J1146+0053  176.705542  0.896136  176.705582  0.896104      sdss
# 8   J1226+0415  186.549542  4.260019  186.549576  4.260018      sdss
# 9   J1444+0409  221.172375  4.161592  221.172363  4.161592      sdss
# 10  J1448-0110  222.022417 -1.182689  222.022415 -1.182700      sdss
# 11  J1624-0022  246.042125 -0.367389  246.042145 -0.367383      sdss
# 12  J2101-0555  315.309958 -5.919525  315.309967 -5.919530      sdss
# 13  J2119+0052  319.992917  0.875986  319.992950  0.875979      sdss
# 14  J2212+0006  333.179375  0.113486  333.179413  0.113483      sdss
# 15  J2215+0002  333.846042  0.046331  333.846069  0.046320      sdss
# 16  J2215-0011  336.292208 -0.198025  336.292206 -0.198011      sdss
# 17  J2337-0010  354.466375 -0.166806  354.466370 -0.166820      sdss
#
#                  SPECOBJID          RA       DEC         Z  ...  log_M  \
# 0   b'439223316213950464 '    5.254286  0.880023  0.098398  ...   9.06
# 1   b'735339668748396544 '    5.915092 -9.813522  0.053035  ...   8.49
# 2   b'1691125637219117056'   24.127474 -0.632222  0.059468  ...   7.79
# 3   b'513494502204270592 '   40.217499 -8.474285  0.082218  ...   7.87
# 4   b'797248221209454592 '   43.142914  1.245541  0.027945  ...   7.27
# 5   b'798423599642863616 '   46.396332  0.683104  0.085573  ...   8.09
# 6   b'300731025703593984 '  147.597183  0.708133  0.097702  ...   8.51
# 7   b'318786936665827328 '  176.705582  0.896104  0.056519  ...   7.65
# 8   b'3242617920756410368'  186.549576  4.260018  0.094233  ...   8.15
# 9   b'661039343871223808 '  221.172363  4.161592  0.038811  ...   6.83
# 10  b'1035986009541601280'  222.022415 -1.182700  0.027398  ...   7.89
# 11  b'409879001813772288 '  246.042145 -0.367383  0.031327  ...   8.27
# 12  b'717307953417316352 '  315.309967 -5.919530  0.196179  ...   8.99
# 13  b'1111371552277948416'  319.992950  0.875979  0.033754  ...   7.76
# 14  b'1243114217410684928'  333.179413  0.113483  0.177042  ...   8.34
# 15  b'1243134008619984896'  333.846069  0.046320  0.077447  ...   8.06
# 16  b'422244936562272256 '  336.292206 -0.198011  0.066681  ...   8.18
# 17  b'767911057829160960 '  354.466370 -0.166820  0.071730  ...   7.86
#
#     log_SFR     Av      ne    chi2 Age_Gyr_err log_M_err  log_SFR_err  \
# 0      1.49  0.890  320.82   0.007         3.0      0.29         0.07
# 1      0.67  0.930  507.99   3.527         2.1      0.06         0.04
# 2      0.03  0.929  539.32   1.960         3.0      0.13         0.05
# 3      0.62  0.780  478.82   0.910         3.0      0.22         0.11
# 4     -0.55  0.930  480.21   2.775         1.9      0.05         0.04
# 5      0.27  0.930  406.37   2.813         2.0      0.04         0.04
# 6      0.99  0.870  331.40   0.019         3.0      0.31         0.08
# 7     -0.09  0.930  495.52   2.892         3.0      0.15         0.05
# 8      0.68  0.790  348.67   0.063         3.0      0.31         0.11
# 9     -0.66  0.290  435.93   2.644         3.1      0.30         0.16
# 10     0.44  0.840  422.99   0.326         3.1      0.30         0.09
# 11     0.69  0.850  422.85   0.478         3.1      0.23         0.09
# 12     1.27  0.929  504.23   0.252         3.0      0.16         0.04
# 13    -0.07  0.930  452.39  10.465         1.6      0.02         0.02
# 14     0.83  0.900  488.93   0.111         3.1      0.29         0.06
# 15     0.49  0.930  462.52   0.249         3.0      0.26         0.04
# 16     0.60  0.910  616.55   0.614         3.0      0.27         0.06
# 17     0.29  0.930  483.75   0.702         3.0      0.26         0.04
#
#      Av_err  ne_err
# 0   0.15000  428.04
# 1   0.00400  472.35
# 2   0.01900  472.65
# 3   0.29000  467.72
# 4   0.00200  470.70
# 5   0.00100  457.19
# 6   0.19000  432.39
# 7   0.04000  472.08
# 8   0.28000  438.91
# 9   0.26000  463.81
# 10  0.24000  461.72
# 11  0.22000  461.95
# 12  0.02500  471.44
# 13  0.00015  461.77
# 14  0.14000  470.53
# 15  0.05000  467.18
# 16  0.10000  460.72
# 17  0.05000  467.29
#
# [18 rows x 434 columns]

# %%
SDSS_tab.to_csv('sdss_contour.csv', index=True)

# %%
SDSS_bpt_selected.to_csv('sdss_bpt.csv', index=True)

# %%
master.columns.values
# Out:
# array(['ID', 'magE_RA', 'magE_DEC', 'sdss_RA', 'sdss_DEC', 'sdss_data',
#        'SPECOBJID', 'RA', 'DEC', 'Z', 'Z_ERR', 'RELIABLE', 'PRIMTARGET',
#        'SECTARGET', 'TARGETTYPE', 'SPECTROTYPE', 'SUBCLASS', 'Z_WARNING',
#        'SPECOBJID', 'MJD', 'PLATEID', 'FIBERID', 'SIGMA_BALMER',
#        'SIGMA_BALMER_ERR', 'SIGMA_FORBIDDEN', 'SIGMA_FORBIDDEN_ERR',
#        'V_OFF_BALMER', 'V_OFF_BALMER_ERR', 'V_OFF_FORBIDDEN',
#        'V_OFF_FORBIDDEN_ERR', 'OII_3726_CONT', 'OII_3726_CONT_ERR',
#        'OII_3726_REQW', 'OII_3726_REQW_ERR', 'OII_3726_EQW',
#        'OII_3726_EQW_ERR', 'OII_3726_SEQW', 'OII_3726_SEQW_ERR',
#        'OII_3726_FLUX', 'OII_3726_FLUX_ERR', 'OII_3726_INST_RES',
#        'OII_3726_CHISQ', 'OII_3729_CONT', 'OII_3729_CONT_ERR',
#        'OII_3729_REQW', 'OII_3729_REQW_ERR', 'OII_3729_EQW',
#        'OII_3729_EQW_ERR', 'OII_3729_SEQW', 'OII_3729_SEQW_ERR',
#        'OII_3729_FLUX', 'OII_3729_FLUX_ERR', 'OII_3729_INST_RES',
#        'OII_3729_CHISQ', 'NEIII_3869_CONT', 'NEIII_3869_CONT_ERR',
#        'NEIII_3869_REQW', 'NEIII_3869_REQW_ERR', 'NEIII_3869_EQW',
#        'NEIII_3869_EQW_ERR', 'NEIII_3869_SEQW', 'NEIII_3869_SEQW_ERR',
#        'NEIII_3869_FLUX', 'NEIII_3869_FLUX_ERR', 'NEIII_3869_INST_RES',
#        'NEIII_3869_CHISQ', 'H_DELTA_CONT', 'H_DELTA_CONT_ERR',
#        'H_DELTA_REQW', 'H_DELTA_REQW_ERR', 'H_DELTA_EQW',
#        'H_DELTA_EQW_ERR', 'H_DELTA_SEQW', 'H_DELTA_SEQW_ERR',
#        'H_DELTA_FLUX', 'H_DELTA_FLUX_ERR', 'H_DELTA_INST_RES',
#        'H_DELTA_CHISQ', 'H_GAMMA_CONT', 'H_GAMMA_CONT_ERR',
#        'H_GAMMA_REQW', 'H_GAMMA_REQW_ERR', 'H_GAMMA_EQW',
#        'H_GAMMA_EQW_ERR', 'H_GAMMA_SEQW', 'H_GAMMA_SEQW_ERR',
#        'H_GAMMA_FLUX', 'H_GAMMA_FLUX_ERR', 'H_GAMMA_INST_RES',
#        'H_GAMMA_CHISQ', 'OIII_4363_CONT', 'OIII_4363_CONT_ERR',
#        'OIII_4363_REQW', 'OIII_4363_REQW_ERR', 'OIII_4363_EQW',
#        'OIII_4363_EQW_ERR', 'OIII_4363_SEQW', 'OIII_4363_SEQW_ERR',
#        'OIII_4363_FLUX', 'OIII_4363_FLUX_ERR', 'OIII_4363_INST_RES',
#        'OIII_4363_CHISQ', 'H_BETA_CONT', 'H_BETA_CONT_ERR', 'H_BETA_REQW',
#        'H_BETA_REQW_ERR', 'H_BETA_EQW', 'H_BETA_EQW_ERR', 'H_BETA_SEQW',
#        'H_BETA_SEQW_ERR', 'H_BETA_FLUX', 'H_BETA_FLUX_ERR',
#        'H_BETA_INST_RES', 'H_BETA_CHISQ', 'OIII_4959_CONT',
#        'OIII_4959_CONT_ERR', 'OIII_4959_REQW', 'OIII_4959_REQW_ERR',
#        'OIII_4959_EQW', 'OIII_4959_EQW_ERR', 'OIII_4959_SEQW',
#        'OIII_4959_SEQW_ERR', 'OIII_4959_FLUX', 'OIII_4959_FLUX_ERR',
#        'OIII_4959_INST_RES', 'OIII_4959_CHISQ', 'OIII_5007_CONT',
#        'OIII_5007_CONT_ERR', 'OIII_5007_REQW', 'OIII_5007_REQW_ERR',
#        'OIII_5007_EQW', 'OIII_5007_EQW_ERR', 'OIII_5007_SEQW',
#        'OIII_5007_SEQW_ERR', 'OIII_5007_FLUX', 'OIII_5007_FLUX_ERR',
#        'OIII_5007_INST_RES', 'OIII_5007_CHISQ', 'HEI_5876_CONT',
#        'HEI_5876_CONT_ERR', 'HEI_5876_REQW', 'HEI_5876_REQW_ERR',
#        'HEI_5876_EQW', 'HEI_5876_EQW_ERR', 'HEI_5876_SEQW',
#        'HEI_5876_SEQW_ERR', 'HEI_5876_FLUX', 'HEI_5876_FLUX_ERR',
#        'HEI_5876_INST_RES', 'HEI_5876_CHISQ', 'OI_6300_CONT',
#        'OI_6300_CONT_ERR', 'OI_6300_REQW', 'OI_6300_REQW_ERR',
#        'OI_6300_EQW', 'OI_6300_EQW_ERR', 'OI_6300_SEQW',
#        'OI_6300_SEQW_ERR', 'OI_6300_FLUX', 'OI_6300_FLUX_ERR',
#        'OI_6300_INST_RES', 'OI_6300_CHISQ', 'NII_6548_CONT',
#        'NII_6548_CONT_ERR', 'NII_6548_REQW', 'NII_6548_REQW_ERR',
#        'NII_6548_EQW', 'NII_6548_EQW_ERR', 'NII_6548_SEQW',
#        'NII_6548_SEQW_ERR', 'NII_6548_FLUX', 'NII_6548_FLUX_ERR',
#        'NII_6548_INST_RES', 'NII_6548_CHISQ', 'H_ALPHA_CONT',
#        'H_ALPHA_CONT_ERR', 'H_ALPHA_REQW', 'H_ALPHA_REQW_ERR',
#        'H_ALPHA_EQW', 'H_ALPHA_EQW_ERR', 'H_ALPHA_SEQW',
#        'H_ALPHA_SEQW_ERR', 'H_ALPHA_FLUX', 'H_ALPHA_FLUX_ERR',
#        'H_ALPHA_INST_RES', 'H_ALPHA_CHISQ', 'NII_6584_CONT',
#        'NII_6584_CONT_ERR', 'NII_6584_REQW', 'NII_6584_REQW_ERR',
#        'NII_6584_EQW', 'NII_6584_EQW_ERR', 'NII_6584_SEQW',
#        'NII_6584_SEQW_ERR', 'NII_6584_FLUX', 'NII_6584_FLUX_ERR',
#        'NII_6584_INST_RES', 'NII_6584_CHISQ', 'SII_6717_CONT',
#        'SII_6717_CONT_ERR', 'SII_6717_REQW', 'SII_6717_REQW_ERR',
#        'SII_6717_EQW', 'SII_6717_EQW_ERR', 'SII_6717_SEQW',
#        'SII_6717_SEQW_ERR', 'SII_6717_FLUX', 'SII_6717_FLUX_ERR',
#        'SII_6717_INST_RES', 'SII_6717_CHISQ', 'SII_6731_CONT',
#        'SII_6731_CONT_ERR', 'SII_6731_REQW', 'SII_6731_REQW_ERR',
#        'SII_6731_EQW', 'SII_6731_EQW_ERR', 'SII_6731_SEQW',
#        'SII_6731_SEQW_ERR', 'SII_6731_FLUX', 'SII_6731_FLUX_ERR',
#        'SII_6731_INST_RES', 'SII_6731_CHISQ', 'ARIII7135_CONT',
#        'ARIII7135_CONT_ERR', 'ARIII7135_REQW', 'ARIII7135_REQW_ERR',
#        'ARIII7135_EQW', 'ARIII7135_EQW_ERR', 'ARIII7135_SEQW',
#        'ARIII7135_SEQW_ERR', 'ARIII7135_FLUX', 'ARIII7135_FLUX_ERR',
#        'ARIII7135_INST_RES', 'ARIII7135_CHISQ', 'H_DELTA_ABS',
#        'H_DELTA_ABS_MODEL', 'H_GAMMA_ABS', 'H_GAMMA_ABS_MODEL',
#        'H_BETA_ABS', 'H_BETA_ABS_MODEL', 'H_ALPHA_ABS',
#        'H_ALPHA_ABS_MODEL', 'CA_K_ABS', 'CA_K_ABS_MODEL', 'CA_H_ABS',
#        'CA_H_ABS_MODEL', 'NA_D_ABS', 'NA_D_ABS_MODEL', 'OII_SIGMA',
#        'OII_FLUX', 'OII_FLUX_ERR', 'OII_VOFF', 'OII_CHI2', 'OIII_SIGMA',
#        'OIII_FLUX', 'OIII_FLUX_ERR', 'OIII_VOFF', 'OIII_CHI2',
#        'SPECTOFIBER', 'SPECOBJID', 'PLATEID', 'MJD', 'FIBERID',
#        'BPTCLASS', 'LGM_TOT_P2P5', 'LGM_TOT_P16', 'LGM_TOT_P50',
#        'LGM_TOT_P84', 'LGM_TOT_P97P5', 'LGM_FIB_P2P5', 'LGM_FIB_P16',
#        'LGM_FIB_P50', 'LGM_FIB_P84', 'LGM_FIB_P97P5', 'OH_P2P5', 'OH_P16',
#        'OH_P50', 'OH_P84', 'OH_P97P5', 'OH_ENTROPY', 'SFR_TOT_P2P5',
#        'SFR_TOT_P16', 'SFR_TOT_P50', 'SFR_TOT_P84', 'SFR_TOT_P97P5',
#        'SFR_TOT_ENTROPY', 'SFR_FIB_P2P5', 'SFR_FIB_P16', 'SFR_FIB_P50',
#        'SFR_FIB_P84', 'SFR_FIB_P97P5', 'SFR_FIB_ENTROPY',
#        'SPECSFR_TOT_P2P5', 'SPECSFR_TOT_P16', 'SPECSFR_TOT_P50',
#        'SPECSFR_TOT_P84', 'SPECSFR_TOT_P97P5', 'SPECSFR_TOT_ENTROPY',
#        'SPECSFR_FIB_P2P5', 'SPECSFR_FIB_P16', 'SPECSFR_FIB_P50',
#        'SPECSFR_FIB_P84', 'SPECSFR_FIB_P97P5', 'SPECSFR_FIB_ENTROPY',
#        'OIII_5007_SNR', 'NII_6584_SNR', 'H_ALPHA_SNR', 'H_BETA_SNR',
#        'R3_S', 'N2_S', 'R3_S_ERR', 'N2_S_ERR', 'LGM_TOT_P5016_ERR',
#        'SFR_TOT_P5016_ERR', 'O32_S', 'O32_S_ERR', 'Ne3O2_S',
#        'Ne3O2_S_ERR', 'N2O2_S', 'N2O2_S_ERR', 'N2S2_S', 'N2S2_S_ERR',
#        'R23_S', 'R23_S_ERR', 'R3N2_S', 'R3N2_S_ERR', 'O3N2_S',
#        'O3N2_S_ERR', 'S2_S', 'S2_S_ERR', 'magE', 'galname', '[OII]3726',
#        '[OII]3726_err', '[OII]3729', '[OII]3729_err', '[NeIII]3868',
#        '[NeIII]3868_err', 'Hd', 'Hd_err', 'Hg', 'Hg_err', '[OIII]4363',
#        '[OIII]4363_err', 'HeI4471', 'HeI4471_err', '[FeIII]4658',
#        '[FeIII]4658_err', 'HeII4686', 'HeII4686_err', '[ArIV]4740',
#        '[ArIV]4740_err', 'Hb', 'Hb_err', '[OIII]4959', '[OIII]4959_err',
#        '[OIII]5007', '[OIII]5007_err', '[NII]5755', '[NII]5755_err',
#        'HeI5875', 'HeI5875_err', '[OI]6300', '[OI]6300_err', '[SIII]6312',
#        '[SIII]6312_err', '[NII]6548', '[NII]6548_err', 'Ha', 'Ha_err',
#        '[NII]6584', '[NII]6584_err', 'HeI6678', 'HeI6678_err',
#        '[SII]6716', '[SII]6716_err', '[SII]6730', '[SII]6730_err',
#        'HeI7065', 'HeI7065_err', '[ArIII]7135', '[ArIII]7135_err',
#        '[OII]7319', '[OII]7319_err', '[OII]7330', '[OII]7330_err',
#        '[SIII]9069', '[SIII]9069_err', '[SIII]9532', '[SIII]9532_err',
#        'Source', '12_log_OH', '12_log_OH_err', '12_log_NH',
#        '12_log_NH_err', 'log_NO', 'log_NO_err', 'N2', 'N2_err', 'R3',
#        'R3_err', 'R2', 'R2_err', 'R23', 'R23_err', 'O3N2', 'O3N2_err',
#        'R3N2', 'R3N2_err', 'N2O2', 'N2O2_err', 'O3O2', 'O3O2_err', 'S2',
#        'S2_err', 'O3S2', 'O3S2_err', 'N2S2', 'N2S2_err', 'Ne3O2',
#        'Ne3O2_err', 'Unnamed: 0', 'ID', 'Age_Gyr', 'log_M', 'log_SFR',
#        'Av', 'ne', 'chi2', 'Age_Gyr_err', 'log_M_err', 'log_SFR_err',
#        'Av_err', 'ne_err'], dtype=object)
