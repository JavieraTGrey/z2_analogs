# %%
import numpy as np
import os
magePath = '/home/benjamin/Documents/analogs/'
os.sys.path.append(magePath)

# %%
ne = np.array([104.70161218699694,  # J2225
               62.486582006901024,  # J2215
               493.4869506684198,   # J0240
               126.04126478902172,  # J0021
               73.5308471200168,    # J0950
               87.03792976380646,   # J1146
               120.01541948854472,  # J1226
               216.71247290609386,  # J1444
               123.73211932825096,  # J1448
               173.15201692925748,  # J2101
               -27.31607527946374]) # J2119 

ne_err = np.array([21.273508603357346,  # J2225
                   20.191516886867404,  # J2215
                   108.14013703032684,  # J0240
                   12.946390991860174,  # J0021
                   29.320662736459653,  # J0950
                   43.41501237029713,   # J1146
                   29.12784607655976,   # J1226
                   48.89556130810314,   # J1444
                   11.182011163654915,  # J1448 
                   32.83676132432046,   # J2101
                   30.896612053047352]) # J2119

# %%
t2 = np.array([1.2832975239764726,  # J2225
               1.6784763550939699,  # J2215
               1.7769641923216,     # J0240
               1.0045242773106748,  # J0021
               1.13229998217458,    # J0950
               1.2458294200592765,  # J1146
               1.2968050508627784,  # J1226
               1.6067318486158741,  # J1444
               0.9428083199553662,  # J1448
               0.9206704870703801,  # J2101
               1.1168024106022534]) # J2119

t2_err = np.array([0.029877553128839034,  # J2225
                   0.03441876623125771,   # J2215
                   0.156779899051408,     # J0240
                   0.015275923037853092,  # J0021
                   0.033853870443273794,  # J0950
                   0.05709437817861606,   # J1146
                   0.034275759464966506,  # J1226
                   0.10006548758712086,   # J1444
                   0.007395186256851372,  # J1448
                   0.022122593031721774,  # J2101
                   0.03908961891791864])  # J2119

# %%
t3 = np.array([1.3211515164513727,  # J2225
               1.1935536783835023,  # J2215
               1.4199629165540797,  # J0240
               1.0602297351466818,  # J0021
               1.208941099192657,   # J0950
               1.8920580908116942,  # J1146
               1.5581692419142343,  # J1226
               1.9388665570793036,  # J1444
               1.3064196007471223,  # J1448
               1.1401079646685333,  # J2101
               1.2653489044712258]) # J2119 

t3_err = np.array([0.01045670864337469,   # J2225
                   0.008492386047713477,  # J2215
                   0.019553683026519313,  # J0240
                   0.008408822097669128,  # J0021
                   0.014272986820475028,  # J0950
                   0.036690103928952146,  # J1146
                   0.02069973442637779,   # J1226
                   0.03619284697425764,   # J1444
                   0.005738324855662954,  # J1448
                   0.014435490936969646,  # J2101
                   0.023713117200149816]) # J2119

# %%
R23 = np.array([0.9843007687877838,  # J2225
                1.006888645855864,   # J2215
                1.0182140922894638,  # J0240
                0.9184747094878155,  # J0021
                0.9643184672278063,  # J0950
                0.992388204833177,   # J1146
                0.9428676028902742,  # J1226
                0.9848518642576272,  # J1444
                1.0076511428267356,  # J1448
                0.9899325412820765,  # J2101
                0.9663488191279057]) # J2119

R23_err = np.array([0.006949493256052936,  # J2225
                    0.0071963051975670765, # J2215
                    0.012097604762672904,  # J0240
                    0.004944156144568638,  # J0021
                    0.011131594691129086,  # J0950
                    0.01338750889335567,   # J1146
                    0.010483947320378384,  # J1226
                    0.012801436741032122,  # J1444
                    0.003995212114595002,  # J1448
                    0.011483488198836923,  # J2101
                    0.016128216991110205]) # J2119

# %%
O32 = np.array([1.1268616629300403,  # J2225
                1.0025888403319176,  # J2215
                1.3421392520458861,  # J0240
                0.6678494202579752,  # J0021
                0.7196551740967453,  # J0950
                1.044423500502135,   # J1146
                0.8708855916038951,  # J1226
                1.219341552773982,   # J1444
                0.8248442700734376,  # J1448
                0.4273716489453919,  # J2101
                0.4712893937527385]) # J2119

O32_err = np.array([0.0062948479757739565, # J2225
                    0.006561502800487463,  # J2215
                    0.010683446936435834,  # J0240
                    0.00470972340466459,   # J0021
                    0.009866295819290449,  # J0950
                    0.011798212605011283,  # J1146
                    0.009110776429226513,  # J1226
                    0.011394093974671114,  # J1444
                    0.003565099614153896,  # J1448
                    0.01039548771987595,   # J2101
                    0.014662093150137645]) # J2119

# %%
N2 = np.array([-1.8136368813284736,  # J2225
               -1.3647840480494018,  # J2215
               -1.7299876792857656,  # J0240
               -1.1577650107057695,  # J0021
               -1.334390422009037,   # J0950
               -2.1478935640123207,  # J1146
               -1.5632753680021394,  # J1226
               -1.9884131128914457,  # J1444
               -1.7942223402283317,  # J1448
               -1.3274462831126645,  # J2101
               -1.4112702190904063]) # J2119

N2_err = np.array([0.006673884082915412,  # J2225
                   0.00610717292334266,   # J2215
                   0.0112056746201309,    # J0240
                   0.004591937499039081,  # J0021
                   0.009628195098702877,  # J0950
                   0.016423586001533787,  # J1146
                   0.009094335356941789,  # J1226
                   0.01282108415915489,   # J1444
                   0.0037256567373789087, # J1448
                   0.010266266506514982,  # J2101
                   0.013923489737008226]) # J2119

# %%
O3N2 = np.array([2.6424688517306456,  # J2225
                 2.207931515893332,   # J2215
                 2.605035402167944,   # J0240
                 1.8694173289402665,  # J0021
                 2.0989906841490353,  # J0950
                 2.9775068743689275,  # J1146
                 2.305594833887167,   # J1226
                 2.8168716337553183,  # J1444
                 2.611489885377734,   # J1448
                 2.0498368980426123,  # J2101
                 2.1194144482649184]) # J2119

O3N2_err = np.array([0.010336943407826463,  # J2225
                     0.010245537721201747,  # J2215
                     0.01763404542787015,   # J0240
                     0.0073984300326497944, # J0021
                     0.016197426953761803,  # J0950
                     0.022438895774934617,  # J1146
                     0.015231013078552288,  # J1226
                     0.019374678118260137,  # J1444
                     0.005952291213092428,  # J1448
                     0.017260754575596643,  # J2101
                     0.02387717912697536])  # J2119

# %%
O_H = np.array([8.050363126324127,  # J2225
                8.169791093058667,  # J2215
                7.98783723041872,   # J0240
                8.307075395295328,  # J0021
                8.162587680883705,  # J0950
                7.744523355915895,  # J1146
                7.853412847723953,  # J1226
                7.659271486286339,  # J1444
                8.217786600552138,  # J1448
                8.418040506011783,  # J2101
                8.144841989524823]) # J2119

O_H_err = np.array([0.01131799155479994,   # J2225
                    0.011490764994033165,  # J2215
                    0.019547683667855427,  # J0240
                    0.01187352819849346,   # J0021
                    0.01887837949768321,   # J0950
                    0.02384058783319034,   # J1146
                    0.016539801441170062,  # J1226
                    0.020614865502012917,  # J1444
                    0.0074606092479613875, # J1448
                    0.028806955903166974,  # J2101
                    0.029883283460059275]) # J2119

# %%
N_H = np.array([5.596926326720036,  # J2225
                5.829389453202847,  # J2215
                5.442361597380998,  # J0240
                6.529038940601482,  # J0021
                6.286934955401438,  # J0950
                5.436140564542963,  # J1146
                5.930548892643317,  # J1226
                5.297864677069555,  # J1444
                6.086785694486686,  # J1448
                6.494359655763046,  # J2101
                6.228952143907187]) # J2119

N_H_err = np.array([0.02313945077656244,  # J2225
                    0.017373154043921625, # J2215
                    0.06706721218294713,  # J0240
                    0.01801860439652205,  # J0021
                    0.03281524529830817,  # J0950
                    0.04732737096505064,  # J1146
                    0.026766534381474097, # J1226
                    0.051781397562040594, # J1444
                    0.010255934190273548, # J1448
                    0.0315208309107413,   # J2101
                    0.04000495045490747]) # J2119

# %%
N_O = np.array([-1.338797526570568,   # J2225
                -0.8826177993359692,  # J2215
                -0.8934072355417647,  # J0240
                -1.1810258423024267,  # J0021
                -1.2348649048473457,  # J0950
                -1.671207559900719,   # J1146
                -1.1979915778284203,  # J1226
                -1.2520614367242597,  # J1444
                -1.6834743417881974,  # J1448
                -1.6363139937505369,  # J2101
                -1.4789591830698028]) # J2119

N_O_err = np.array([0.0151025328056232,    # J2225
                    0.011108730017272814,  # J2215
                    0.03823892082309646,   # J0240
                    0.012140750430530202,  # J0021
                    0.02173474142873876,   # J0950
                    0.03181495540790494,   # J1146
                    0.017628737812734725,  # J1226
                    0.03148662665921458,   # J1444
                    0.007194546898841022,  # J1448
                    0.021702255749496437,  # J2101
                    0.027073584523812016]) # J2119

# %%
N2_cont = np.linspace(min(N2), max(N2), 100)
O3N2_cont = np.linspace(min(O3N2), max(O3N2), 100)
O32_cont = np.linspace(min(O32), max(O32), 100)
R23_cont = np.linspace(min(R23), max(R23), 100)
LOG_OH_cont = np.linspace(min(O_H), max(O_H), 100)

OH_N2_PP2004 = 8.90 + (0.57 * N2_cont)
OH_O3N2_PP2004 = 8.73 - (0.32 * O3N2_cont)

LA_OH_N2_BIAN21 = 8.82 + (0.49 * N2_cont)
LA_OH_O3N2_BIAN21 = 8.97 - (0.39 * O3N2_cont)

SDSS_OH_N2_BIAN21 = 8.98 + (0.63 * N2_cont)
SDSS_OH_O3N2_BIAN21 = 9.05 - (0.47 * O3N2_cont)

EELGs_OH_N2_EPM21 = 8.625 + (0.361 * N2_cont)
EELGs_OH_O3N2_EPM21 = 8.677 - (0.270 * O3N2_cont)

LA_OH_O32_BIAN21 = 8.54 - (0.59 * O32_cont)
EELGs_OH_O32_EPM21 = 8.308 - (0.352 * O32_cont)

LA_R23_OH_BIAN21 = 138.0430 - (54.8284 * LOG_OH_cont) + (7.2954 * LOG_OH_cont**2) - (0.32293 * LOG_OH_cont**3)

# %%
# %matplotlib inline

# %%
from magE.plotutils import *
texPlot('on')
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches((15, 6))

ax1.errorbar(N2, O_H, xerr=N2_err, yerr=O_H_err, 
             ls='', marker='o', capsize=5, 
             markersize=6, color=c[0],
             label='This work')
ax1.plot(N2_cont, OH_N2_PP2004, color=c[1], lw=2, label='PP04')
ax1.plot(N2_cont, LA_OH_N2_BIAN21, color=c[2], lw=2, ls='--', label='Analogs (B21)')
ax1.plot(N2_cont, SDSS_OH_N2_BIAN21, color=c[3], lw=2, ls='-.', label='SDSS galaxies (B21)')
ax1.plot(N2_cont, EELGs_OH_N2_EPM21, color=czp[1], lw=2, ls=':', label='EELGs (PM21)')
ax1.set_ylabel('12 + log(O/H)', fontsize=20)
ax1.set_xlabel('N2', fontsize=20)

ax2.errorbar(O3N2, O_H, xerr=O3N2_err, yerr=O_H_err, 
             ls='', marker='o', capsize=5,
             markersize=4, color=c[0],
             label='This work')
ax2.plot(O3N2_cont, OH_O3N2_PP2004, color=c[1], lw=2, label='PP04')
ax2.plot(O3N2_cont, LA_OH_O3N2_BIAN21, color=c[2], lw=2, ls='--', label='Analogs (B21)')
ax2.plot(O3N2_cont, SDSS_OH_O3N2_BIAN21, color=c[3], lw=2, ls='-.', label='SDSS galaxies (B21)')
ax2.plot(O3N2_cont, EELGs_OH_O3N2_EPM21, color=czp[1], lw=2, ls=':', label='EELGs (PM21)')
ax2.set_ylabel('12 + log(O/H)', fontsize=20)
ax2.set_xlabel('O3N2', fontsize=20)
ax2.legend(loc='lower left', frameon=False, fontsize='x-large')
#plt.savefig(fname='OH_N2_O3N2.svg', bbox_inches='tight', facecolor='white')

# %%
from magE.plotutils import *
texPlot('on')
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches((15, 6))

ax1.errorbar(O32, O_H, xerr=O32_err, yerr=O_H_err, 
             ls='', marker='o', capsize=5, 
             markersize=6, color=c[0],
             label='This work')
ax1.plot(O32_cont, LA_OH_O32_BIAN21, color=c[2], lw=2, ls='--', label='Analogs (B21)')
ax1.plot(O32_cont, EELGs_OH_O32_EPM21, color=czp[1], lw=2, ls=':', label='EELGs (PM21)')
ax1.set_ylabel('12 + log(O/H)', fontsize=20)
ax1.legend(loc='lower left', frameon=False, fontsize='x-large')
ax1.set_xlabel('O32', fontsize=20)

ax2.errorbar(R23, O_H, xerr=R23_err, yerr=O_H_err, 
             ls='', marker='o', capsize=5,
             markersize=4, color=c[0],
             label='This work')
ax2.plot(LA_R23_OH_BIAN21, LOG_OH_cont, color=c[2], lw=2, ls='--', label='Analogs (B21)')
ax2.set_ylabel('12 + log(O/H)', fontsize=20)
ax2.set_xlabel('R23', fontsize=20)
#plt.savefig(fname='OH_O32_R23.svg', bbox_inches='tight', facecolor='white')
# Out:
# Text(0.5, 0, 'R23')

# %%
# J0023, J0136, J0252, J0305, J2212, J2337

ha_nii_ratio = np.array([0.026957444158306147, 0.017096855799433562, 0.01909042177005595, 0.04725153075349324, 0.062414673236708365, 0.01591505795286228])
ha_nii_ratio_err = np.array([0.00024257732269942475, 0.000444359875883622, 0.0004719780916751935, 0.0006188826231451327, 0.0010513421163065154, 0.00021034666580782202])

#ha_nii_ratio_box = np.array([0.02153475738017582, 0.014980385456821212, 0.013682993335177236, 0.04341492517606951, 0.05237253472591902, 0.013301685476898776])
#ha_nii_ratio_box_err = np.array([0.0004460965248328873, 0.0009416344493767324, 0.0008763408875219317, 0.00306007318969872, 0.005144915276779083, 0.000328739017073233])

ha_nii_ratio_box = np.array([0.02000931860177462, 0.014245733818722508, 0.014282878241017758, 0.04461580765934643, 0.059966747900440785, 0.014224857260237478])
ha_nii_ratio_box_err = np.array([0.0002947451097658911, 0.0004136915518337925, 0.00041007094242784167, 0.0006461259570378512, 0.0010922231928019441, 0.00021337303203791276])

#ha_nii_sdss_ratio = np.array([0.023497806532927535, 0.016497999672669354, 0.018499724935405, 0.04809293536286835, 0.05336466953606062, 0.015772166879220027])
#ha_nii_sdss_ratio_err = np.array([0.0004557401072852369, 0.0009736623168051905, 0.0007851806918171306, 0.0014265906491287045, 0.004273262122697221, 0.0006836636392359636])

ha_nii_sdss_ratio = np.array([0.023064725873216667, 0.016874011156770296, 0.018002450094291998, 0.05028817640557145, 0.06132612918161585, 0.015345287897537342])
ha_nii_sdss_ratio_err = np.array([0.0005265247107002107, 0.0011148491815833408, 0.0008545546020277834, 0.001663706617683772, 0.004765347009607802, 0.0007712051919090103])

oiiia_hb_ratio = np.array([8.518143735041722, 9.326349960901382, 6.315062669229314, 5.642993552614766, 5.145615606657044, 7.237163560099887])
oiiia_hb_ratio_err = np.array([0.028518892029003387, 0.05099585042812983, 0.03437217556171715, 0.02659838674998094, 0.02540964972097656, 0.01869762928787601])

#oiiia_hb_ratio_box = np.array([7.50139111255723, 13.256598741642488, 11.852819165823659, 6.370026262712458, 5.87271134673693, 7.603128967558383])
#oiiia_hb_ratio_box_err = np.array([0.04993394320563417, 0.14981037737101266, 0.17493127517717685, 0.15546141103123579, 0.1540550207413219, 0.030628795300370527])

oiiia_hb_ratio_box = np.array([7.4616666094603605, 13.557672569660964, 11.634075864999284, 5.874819435277157, 5.493279416063144, 7.439150460565406])
oiiia_hb_ratio_box_err = np.array([0.030014365802273, 0.0644434514121647, 0.05972752607823535, 0.029457035874869288, 0.027363819124677575, 0.021029181547954433])

#oiiia_hb_sdss_ratio = np.array([6.223548679117459, 7.211788912149114, 7.328895412942928, 5.5044417897517555, 5.079546201245925, 6.961419085546126])
#oiiia_hb_sdss_ratio_err = np.array([0.06344203678613468, 0.09785990172065913, 0.10877642307711956, 0.08627956079698253, 0.10559733307577042, 0.09105942700395116])

oiiia_hb_sdss_ratio = np.array([6.441638795576188, 7.514454920816375, 7.489002108098295, 5.735500906812658, 5.195427802069863, 7.204272796627554])
oiiia_hb_sdss_ratio_err = np.array([0.07550380313585517, 0.11728339331116623, 0.1260659515850725, 0.10103415764552684, 0.12035050435427627, 0.10827587953099603])

ha_hb_ratio = np.array([3.8046968346334227, 2.908337366359453, 2.697796163626889, 3.5848093581817557, 2.8443499655807605, 3.417735633734428])
ha_hb_ratio_err = np.array([0.012050597223618937, 0.01482338440894683, 0.015139483562179142, 0.01688576697501822, 0.014344805525779825, 0.009009169339200658])

#ha_hb_ratio_box = np.array([3.7452759784146834, 3.0670981436779314, 2.989054647962716, 3.866514141173615, 3.4276972392971374, 3.5178827743438554])
#ha_hb_ratio_box_err = np.array([0.02543828869591079, 0.03707560142743398, 0.045518300477986565, 0.08860487267179766, 0.08545448667675434, 0.014366692409566482])

ha_hb_ratio_box = np.array([3.8751721231265748, 5.264132421384266, 3.9125359486068083, 3.74295526359629, 3.4125784791429243, 3.4691393544245286])
ha_hb_ratio_box_err = np.array([0.01585817299931373, 0.025720470227391514, 0.02072569552626064, 0.01910425707843057, 0.017254460744924906, 0.01007390386365855])

#ha_hb_sdss_ratio = np.array([3.690663405174286, 3.029530927541588, 2.7989302538011245, 3.329787303091472, 3.050127559188956, 3.4609268206742767])
#ha_hb_sdss_ratio_err = np.array([0.03773015160930625, 0.04029970629374008, 0.04136298367295958, 0.05196684281105684, 0.07108692328054321, 0.04670461036448279])

ha_hb_sdss_ratio = np.array([3.9425900038056816, 3.215491116133805, 3.0795519401123377, 3.650623630522639, 3.2183977144635576, 3.6390508416603824])
ha_hb_sdss_ratio_err = np.array([0.04673938181288621, 0.049999078422775005, 0.05212957282685859, 0.06405555495975206, 0.08241384825047995, 0.056818392879808305])

gals = ['J0023', 'J0136', 'J0252', 'J0305', 'J2212', 'J2337']

# %%
plt.figure()
plt.errorbar(gals, ha_nii_ratio, ha_nii_ratio_err, fmt='o', capsize=10, label='Measured')
plt.errorbar(gals, ha_nii_sdss_ratio, ha_nii_sdss_ratio_err, fmt='o', capsize=10, label='SDSS')
plt.errorbar(gals, ha_nii_ratio_box, ha_nii_ratio_box_err, fmt='o', capsize=10, label='Boxcar')
plt.ylabel(r'[NII]/H$\alpha$')
plt.xlabel('2019B night galaxy')
plt.legend(frameon=True)
plt.grid(visible=True)
plt.savefig('ha_ratio.svg', bbox_inches='tight', facecolor='white')

# %%
plt.figure()
plt.errorbar(gals, ha_hb_ratio, ha_hb_ratio_err, fmt='o', capsize=10, label='Measured')
plt.errorbar(gals, ha_hb_sdss_ratio, ha_hb_sdss_ratio_err, fmt='o', capsize=10, label='SDSS')
plt.errorbar(gals, ha_hb_ratio_box, ha_hb_ratio_box_err, fmt='o', capsize=10, label='Boxcar')
plt.ylabel(r'H$\alpha$/H$\beta$')
plt.xlabel('2019B night galaxy')
plt.legend(frameon=True)
plt.grid(visible=True)
plt.savefig('ha_hb_ratio.svg', bbox_inches='tight', facecolor='white')

# %%
plt.figure()
plt.errorbar(gals, oiiia_hb_ratio, oiiia_hb_ratio_err, fmt='o', capsize=10, label='Measured')
plt.errorbar(gals, oiiia_hb_sdss_ratio, oiiia_hb_sdss_ratio_err, fmt='o', capsize=10, label='SDSS')
plt.errorbar(gals, oiiia_hb_ratio_box, oiiia_hb_ratio_box_err, fmt='o', capsize=10, label='Boxcar')
plt.ylabel(r'[OIII]/H$\beta$')
plt.xlabel('2019B night galaxy')
plt.legend(frameon=True)
plt.grid(visible=True)
plt.savefig('hb_ratio.svg', bbox_inches='tight', facecolor='white')

# %%
os.getcwd()
# Out:
# '/home/benjamin/Documents/analogs/metals'

# %%
# %matplotlib inline

plt.errorbar(N2, O_H, xerr=N2_err, yerr=O_H_err, ls='', marker='o', capsize=5, markersize=4, label='This work')
plt.plot(N2_cont, OH_N2_PP2004, label='PP04')
plt.plot(N2_cont, LA_OH_N2_BIAN21, ls='--', label='Analogs (B21)')
plt.plot(N2_cont, SDSS_OH_N2_BIAN21, ls='-.', label='SDSS galaxies (B21)')
plt.plot(N2_cont, EELGs_OH_N2_EPM21, ls=':', label='EELGs (PM21)')
plt.ylabel('12 + log(O/H)')
plt.xlabel('N2')
plt.legend(frameon=False)
#plt.savefig(fname='OH_N2.jpg', bbox_inches='tight')

# %%
plt.errorbar(O3N2, O_H, xerr=O3N2_err, yerr=O_H_err, ls='', marker='o', capsize=5, markersize=4, label='This work')
plt.plot(O3N2_cont, OH_O3N2_PP2004, label='PP04')
plt.plot(O3N2_cont, LA_OH_O3N2_BIAN21, ls='--', label='Analogs (B21)')
plt.plot(O3N2_cont, SDSS_OH_O3N2_BIAN21, ls='-.', label='SDSS galaxies (B21)')
plt.plot(O3N2_cont, EELGs_OH_O3N2_EPM21, ls=':', label='EELGs (PM21)')
plt.ylabel('12 + log(O/H)')
plt.xlabel('O3N2')
plt.legend(loc='lower left', frameon=False)
#plt.savefig(fname='OH_O3N2.jpg', bbox_inches='tight')

# %%
plt.errorbar(R23, O_H, xerr=R23_err, yerr=O_H_err, ls='', marker='o', capsize=5, markersize=4)
plt.ylabel('12 + log(O/H)')
plt.xlabel('R23')
# Out:
# Text(0.5, 0, 'R23')

# %%
plt.errorbar(O32, O_H, xerr=O32_err, yerr=O_H_err, ls='', marker='o', capsize=5, markersize=4)
plt.ylabel('12 + log(O/H)')
plt.xlabel('O32')
# Out:
# Text(0.5, 0, 'O32')

# %%
OH_N2_PP2004 = 8.90 + (0.57 * N2)
OH_O3N2_PP2004 = 8.73 - (0.32 * O3N2)

LA_OH_N2_BIAN21 = 8.82 + (0.49 * N2)
LA_OH_O3N2_BIAN21 = 8.97 - (0.39 * O3N2)

SDSS_OH_N2_BIAN21 = 8.98 + (0.63 * N2)
SDSS_OH_O3N2_BIAN21 = 9.05 - (0.47 * O3N2)

EELGs_OH_N2_EPM21 = 8.625 + (0.361 * N2)
EELGs_OH_O3N2_EPM21 = 8.677 - (0.270 * O3N2)

# %%
print(min(np.abs(LA_OH_N2_BIAN21- O_H)))
print(min(np.abs(EELGs_OH_N2_EPM21 - O_H)))
# Out:
# 0.0035610123318665643
# 0.012637217359118047

# %%
print(max(np.abs(LA_OH_N2_BIAN21- O_H)))
print(max(np.abs(EELGs_OH_N2_EPM21 - O_H)))
# Out:
# 0.27695554726401994
# 0.27224861421545477

# %%
print(min(np.abs(LA_OH_O3N2_BIAN21- O_H)))
print(min(np.abs(EELGs_OH_O3N2_EPM21 - O_H)))
# Out:
# 0.0014136243481406296
# 0.014196789004065735

# %%
print(max(np.abs(LA_OH_O3N2_BIAN21- O_H)))
print(max(np.abs(EELGs_OH_O3N2_EPM21 - O_H)))
# Out:
# 0.2662676558494539
# 0.29449646848328825

# %% [markdown]
# # Test electron density

# %%
from astropy.io import fits
galSpecLine = fits.open('/home/nava/Descargas/galSpecLine-dr8.fits')
galSpecInfo = fits.open('/home/nava/Descargas/galSpecInfo-dr8.fits')
galSpecExtra = fits.open('/home/nava/Descargas/galSpecInfo-dr8.fits')
#specObj_dr14 = fits.open('specObj-dr14.fits')

galSpecLine_data = galSpecLine[1].data
galSpecInfo_data = galSpecInfo[1].data
galSpecExtra_data = galSpecExtra[1].data

# %%
J2225_fits = fits.open(PATH + 'j2225-0011_fcal_final.fits')
data_galaxy = J2225_fits[0].header
print(data_galaxy['RA-D'], data_galaxy['DEC-D'])
specObjID_J2225 = '422244936562272256'
mask_J2225 = galSpecLine_data['SPECOBJID'] == specObjID_J2225

# %%
SII_6717 = galSpecLine[1].data['sii_6717_flux'][mask_J2225]
SII_6731 = galSpecLine[1].data['sii_6731_flux'][mask_J2225]

OIII_4363 = galSpecLine[1].data['oiii_4363_flux'][mask_J2225]
OIII_4959 = galSpecLine[1].data['oiii_4959_flux'][mask_J2225]
OIII_5007 = galSpecLine[1].data['oiii_5007_flux'][mask_J2225]

# %%
RO3 = (OIII_4363 + OIII_4959) / OIII_5007
RS2 = SII_6717 / SII_6731
tOIII = 0.7840 - 0.0001357 * RO3 + (48.44 / RO3)

a0 = 16.054 - (7.79 / tOIII) - (11.32 * tOIII)
a1 = -22.66 + (11.08 / tOIII) + (16.02 * tOIII)
b0 = -21.61 + (11.89 / tOIII) + (14.59 * tOIII)
b1 = 9.17 - (5.09 / tOIII) - (6.18 * tOIII)
num = (RS2 * a0) + a1
den = (RS2 * b0) + b1
ne = (num / den) * 1e3

# %%
ne
